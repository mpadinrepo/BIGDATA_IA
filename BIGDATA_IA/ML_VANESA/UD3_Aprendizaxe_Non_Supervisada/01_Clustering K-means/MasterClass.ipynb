# %% [markdown]
# 1) Explicación básica del algoritmo,
# 2) Cómo se implementa en Python utilizando la biblioteca scikit-learn
# 3) Ejemplos prácticos

# %% [markdown]
# ================================================================
#
# 1. Introducción al algoritmo K-means:
#
# El algoritmo K-means es uno de los métodos de clustering más populares y simples. Su objetivo es particionar un conjunto de datos en K grupos (clusters) diferentes, donde cada punto de datos pertenece al cluster con el centroide más cercano. El algoritmo funciona iterativamente para asignar cada punto a su cluster más cercano y luego actualizar los centroides de cada cluster basándose en los puntos asignados. Este proceso se repite hasta que los centroides ya no cambian significativamente o se alcanza un número máximo de iteraciones.

# %% [markdown]
# 2. Implementación en Python con scikit-learn:
#
# Ahora vamos a ver cómo implementar K-means en Python utilizando la biblioteca scikit-learn. Primero, necesitaremos importar las bibliotecas necesarias y cargar nuestros datos:

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn.datasets import make_blobs

# Generar datos sintéticos
X, _ = make_blobs(n_samples=300, centers=4, cluster_std=0.60, random_state=0)

# Visualizar los datos
plt.scatter(X[:, 0], X[:, 1], s=50)
plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
plt.title('Conjunto de datos de ejemplo')
plt.show()

# %% [markdown]
# Ahora que tenemos nuestros datos, podemos aplicar el algoritmo K-means:

# %%
# Inicializar el modelo K-means
kmeans = KMeans(n_clusters=4)

# Ajustar el modelo a los datos
kmeans.fit(X)

# Obtener las etiquetas de los clusters y los centroides
labels = kmeans.labels_
centroids = kmeans.cluster_centers_

# Visualizar los clusters y los centroides
plt.scatter(X[:, 0], X[:, 1], c=labels, s=50, cmap='viridis')
plt.scatter(centroids[:, 0], centroids[:, 1], marker='o', s=200, color='red', edgecolor='black')
plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
plt.title('Clustering con K-means')
plt.show()

# %% [markdown]
# 3. Ejemplos prácticos:
#
#     Segmentación de clientes: Utilizar K-means para agrupar clientes en función de su comportamiento de compra para realizar estrategias de marketing específicas para cada segmento.
#     Compresión de imágenes: Aplicar K-means para reducir el número de colores en una imagen, manteniendo la calidad visual pero reduciendo el tamaño del archivo.
#     Análisis de redes sociales: Utilizar K-means para identificar comunidades de usuarios con intereses similares en una red social, como grupos de fans de ciertos deportes o géneros musicales.

# %%
# Importar las bibliotecas necesarias
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn.datasets import make_blobs

# %% [markdown]
# Lo que se necesita: Importar las bibliotecas necesarias para realizar el clustering con K-means.
#
#
# Lo que se obtiene: Se importan las bibliotecas numpy, matplotlib.pyplot, sklearn.cluster.KMeans y sklearn.datasets.make_blobs.
#
#
# Conclusiones: En esta línea, se prepara el entorno de trabajo importando las herramientas necesarias para la implementación del algoritmo K-means y la generación de datos de ejemplo

# %%
# Generar datos sintéticos
X, _ = make_blobs(n_samples=300, centers=4, cluster_std=0.60, random_state=0)

# %% [markdown]
# Lo que se necesita: Generar un conjunto de datos sintéticos para aplicar el algoritmo K-means.
#
#
# Lo que se obtiene: Se genera un conjunto de datos X utilizando la función make_blobs con 300 muestras, 4 centros, un desviación estándar de 0.60 y una semilla aleatoria.
#
#
# Conclusiones: Esta línea crea un conjunto de datos de ejemplo con características aleatorias, que se utilizará para aplicar el algoritmo K-means y demostrar su funcionamiento.

# %%
# Visualizar los datos
plt.scatter(X[:, 0], X[:, 1], s=50)
plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
plt.title('Conjunto de datos de ejemplo')
plt.show()

# %% [markdown]
# Lo que se necesita: Visualizar los datos generados para entender su distribución antes de aplicar el algoritmo K-means.
#
#
# Lo que se obtiene: Se genera un gráfico de dispersión que muestra las características del conjunto de datos X.
#
#
# Conclusiones: Esta línea permite visualizar los datos en un espacio bidimensional, lo que facilita la comprensión de la distribución de los puntos y ayuda a determinar el número adecuado de clusters.

# %%
# Inicializar el modelo K-means
kmeans = KMeans(n_clusters=4)

# %% [markdown]
# Lo que se necesita: Inicializar el modelo K-means con un número específico de clusters.
#
# Lo que se obtiene: Se crea una instancia del modelo KMeans con 4 clusters.
#
# Conclusiones: Esta línea establece los parámetros iniciales del modelo K-means, especificando el número de clusters que se utilizarán para agrupar los datos.

# %%
# Ajustar el modelo a los datos
kmeans.fit(X)
# Out:
# KMeans(n_clusters=4)

# %% [markdown]
# Lo que se necesita: Aplicar el algoritmo K-means a los datos.
#
# Lo que se obtiene: Se ajusta el modelo KMeans a los datos X.
#
# Conclusiones: Esta línea ejecuta el algoritmo K-means en el conjunto de datos, lo que significa que los centroides se calculan y los puntos de datos se asignan a los clusters correspondientes.

# %%
# Obtener las etiquetas de los clusters y los centroides
labels = kmeans.labels_
centroids = kmeans.cluster_centers_

# %% [markdown]
# Lo que se necesita: Obtener las etiquetas de los clusters y las coordenadas de los centroides.
#
# Lo que se obtiene: Se asignan las etiquetas de los clusters a cada punto de datos y se obtienen las coordenadas de los centroides
#
# Conclusiones: Esta línea proporciona información sobre cómo se agrupan los datos y dónde se encuentran los centroides de cada cluster.

# %%
# Visualizar los clusters y los centroides
plt.scatter(X[:, 0], X[:, 1], c=labels, s=50, cmap='viridis')
plt.scatter(centroids[:, 0], centroids[:, 1], marker='o', s=200, color='red', edgecolor='black')
plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
plt.title('Clustering con K-means')
plt.show()

# %% [markdown]
# Lo que se necesita: Visualizar los clusters resultantes y los centroides.
#
# Lo que se obtiene: Se genera un gráfico de dispersión que muestra los clusters coloreados y los centroides resaltados en rojo.
#
# Conclusiones: Esta línea muestra visualmente cómo se han agrupado los datos y dónde están ubicados los centroides de cada cluster después de aplicar el algoritmo K-means.
