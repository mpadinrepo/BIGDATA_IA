# %%
from pymongo import MongoClient
from pymongo.errors import ConnectionFailure

try:
    # Intenta establecer la conexión
    client = MongoClient('172.18.0.1', 27017)
    # Verifica si la conexión está disponible
    client.admin.command('ismaster')
    print("Conexión exitosa")

    # Seleccionar la base de datos
    db = client.supermercado
    # Seleccionar la colección
    collection = db.pedidos

    # Eliminar todos los documentos de la colección
    result = collection.delete_many({})

    print(f"Se han eliminado {result.deleted_count} documentos de la colección 'pedidos'.")

except ConnectionFailure:
    # Captura la excepción si la conexión falla
    print("Error al conectar con el servidor de MongoDB")
# Out:
# Conexión exitosa
# Se han eliminado 0 documentos de la colección 'pedidos'.

# %%
from pymongo import MongoClient
from pymongo.errors import ConnectionFailure
import json

try:
    # Intenta establecer la conexión
    client = MongoClient('172.18.0.1', 27017)
    # Verifica si la conexión está disponible
    client.admin.command('ismaster')
    print("Conexión exitosa")

    # Seleccionar la base de datos
    db = client.supermercado
    # Seleccionar la colección
    collection = db.pedidos

    # Abrir el archivo JSON y leer cada línea
    with open('ventas.json', 'r') as file:
        lines = file.readlines()
        for line in lines:
            # Cargar la línea como un objeto JSON
            data = json.loads(line)
            # Desanidar el campo _id y asignarlo directamente
            data['_id'] = data['_id']['$oid']
            # Insertar los datos en la colección
            collection.insert_one(data)

    print("Documentos importados correctamente.")

except ConnectionFailure:
    # Captura la excepción si la conexión falla
    print("Error al conectar con el servidor de MongoDB")
# Out:
# Conexión exitosa
# Documentos importados correctamente.

# %%
num_documentos = collection.count_documents({})
print("Número total de registros importados:", num_documentos)
# Out:
# Número total de registros importados: 2999

# %%
pedido_47371 = collection.find_one({"ID_Pedido": 47371})
print(pedido_47371)
# Out:
# {'_id': '630a3d935f6bf41f76dcb2de', 'ID_Pedido': 47371, 'Importe total': 110.151, 'Fecha de compra': {'$date': '2020-10-14T00:00:00Z'}, 'Número de items': 2, 'Cliente': {'ID_Cliente': 54, 'Nombre': 'José', 'Apellido1': 'González', 'Apellido2': 'Álvarez', 'Dirección': {'ID_Dirección': 28, 'Calle': 'Avenida de Carlos', 'Número': 2, 'Piso': '1A', 'Código Postal': 45610, 'Localidad': 'Navalcán', 'Provincia': 'Toledo'}}}

# %%
pedido_47371_info = collection.find_one({"ID_Pedido": 47371}, {"_id": 0, "ID_Pedido": 1, "Importe total": 1})
print(pedido_47371_info)
# Out:
# {'ID_Pedido': 47371, 'Importe total': 110.151}

# %%
pedido_info = collection.find_one({"ID_Pedido": 47371}, {"_id": 1, "Cliente.Dirección.Código Postal": 1})
print(pedido_info)
# Out:
# {'_id': '630a3d935f6bf41f76dcb2de', 'Cliente': {'Dirección': {'Código Postal': 45610}}}

# %%
num_pedidos_sin_direccion = collection.count_documents({"Cliente.Dirección": {"$exists": False}})
print(num_pedidos_sin_direccion)
# Out:
# 0

# %%
num_pedidos_con_cliente = collection.count_documents({"Cliente": {"$exists": True}})
print(num_pedidos_con_cliente)
# Out:
# 2999

# %%
pedido_mayor_importe = collection.find_one(sort=[("Importe total", -1)])

if pedido_mayor_importe:
    id_pedido_mayor_importe = pedido_mayor_importe["ID_Pedido"]
    datos_cliente = pedido_mayor_importe["Cliente"]
    print("ID_Pedido:", id_pedido_mayor_importe)
    print("Datos del cliente:")
    print("ID_Cliente:", datos_cliente["ID_Cliente"])
    print("Nombre:", datos_cliente["Nombre"])
    print("Apellido1:", datos_cliente["Apellido1"])
    print("Apellido2:", datos_cliente["Apellido2"])
else:
    print("No se encontró ningún pedido.")
# Out:
# ID_Pedido: 79138
# Datos del cliente:
# ID_Cliente: 95
# Nombre: Eduardo
# Apellido1: Pérez
# Apellido2: González

# %%
pedidos_con_mas_de_5_items = collection.distinct("ID_Pedido", {"Número de items": {"$gt": 5}})
print("ID_Pedido con más de 5 items:", pedidos_con_mas_de_5_items)
# Out:
# ID_Pedido con más de 5 items: [30521, 67569, 67693]

# %%
pedidos_cliente_1_40_45 = collection.find(
    {"Cliente.ID_Cliente": 1, "Importe total": {"$gte": 40, "$lte": 45}},
    {"ID_Pedido": 1, "Importe total": 1, "_id": 0}
)
for pedido in pedidos_cliente_1_40_45:
    print(pedido)
# Out:
# {'ID_Pedido': 60845, 'Importe total': 44.255}
# {'ID_Pedido': 72047, 'Importe total': 41.612}
# {'ID_Pedido': 45540, 'Importe total': 41.718}

# %%
num_pedidos_sin_numero = collection.count_documents({
    "Cliente.Dirección.Número": {"$exists": False}
})

num_pedidos_sin_piso = collection.count_documents({
    "Cliente.Dirección.Piso": {"$exists": False}
})

num_pedidos_sin_numero_o_piso = num_pedidos_sin_numero + num_pedidos_sin_piso

print("Número de pedidos con direcciones sin Número o Piso:", num_pedidos_sin_numero_o_piso)
# Out:
# Número de pedidos con direcciones sin Número o Piso: 2624

# %%
id_direcciones_distintas = collection.distinct("Cliente.Dirección.ID_Dirección", {
    "$or": [
        {"Cliente.Dirección.Número": {"$exists": False}},
        {"Cliente.Dirección.Piso": {"$exists": False}}
    ]
})

print("Valores distintos de ID_Dirección de los pedidos sin Número o Piso:", id_direcciones_distintas)
# Out:
# Valores distintos de ID_Dirección de los pedidos sin Número o Piso: [3, 6, 7, 8, 10, 11, 13, 16, 17, 19, 21, 25, 29, 31, 33, 35, 37, 45]

# %%
# 2. Identificar documentos que cumplen con las condiciones de actualización
# (Puedes realizar consultas para encontrar documentos que necesitan ser actualizados)
documents_to_update = collection.find({
    "Cliente.Dirección.Número": {"$exists": False}
})
print("\nDocumentos que necesitan actualización:")
for doc in documents_to_update:
    print(doc)

# 3. Diseñar consultas de actualización basadas en los datos revisados
# (Puedes crear consultas de actualización para corregir los datos faltantes)
update_query = {
    "$set": {"Cliente.Dirección.Incompleto": "SI"}
}

# Actualizar documentos que cumplen con la condición
result = collection.update_many(
    {"Cliente.Dirección.Número": {"$exists": False}},
    update_query
)
print(f"\nSe actualizaron {result.modified_count} documentos.")
# Out:
# Documentos que necesitan actualización:
# {'_id': '630a3d935f6bf41f76dcb29c', 'ID_Pedido': 52865, 'Importe total': 61.583, 'Fecha de compra': {'$date': '2016-10-03T00:00:00Z'}, 'Número de items': 2, 'Cliente': {'ID_Cliente': 76, 'Nombre': 'Tomás', 'Apellido1': 'Gándara', 'Apellido2': 'Fernández', 'Dirección': {'Incompleto': 'SI'}}}
# {'_id': '630a3d935f6bf41f76dcb2a1', 'ID_Pedido': 73667, 'Importe total': 14.878, 'Fecha de compra': {'$date': '2016-09-25T00:00:00Z'}, 'Número de items': 3, 'Cliente': {'ID_Cliente': 8, 'Nombre': 'Juan', 'Apellido1': 'Gándara', 'Apellido2': 'Álvarez', 'Dirección': {'Incompleto': 'SI'}}}
# {'_id': '630a3d935f6bf41f76dcb2a9', 'ID_Pedido': 46269, 'Importe total': 106.09, 'Fecha de compra': {'$date': '2021-09-20T00:00:00Z'}, 'Número de items': 1, 'Cliente': {'Dirección': {'Incompleto': 'SI'}}}
# {'_id': '630a3d935f6bf41f76dcb2ae', 'ID_Pedido': 77194, 'Importe total': 64.401, 'Fecha de compra': {'$date': '2021-10-11T00:00:00Z'}, 'Número de items': 2, 'Cliente': {'ID_Cliente': 59, 'Nombre': 'Teresa', 'Apellido1': 'Álvarez', 'Apellido2': 'Hernández', 'Dirección': {'Incompleto': 'SI'}}}
# {'_id': '630a3d935f6bf41f76dcb2af', 'ID_Pedido': 33472, 'Importe total': 88.123, 'Fecha de compra': {'$date': '2022-06-04T00:00:00Z'}, 'Número de items': 3, 'Cliente': {'ID_Cliente': 3, 'Nombre': 'Jesús', 'Apellido1': 'González', 'Apellido2': 'Hernández', 'Dirección': {'Incompleto': 'SI'}}}
# {'_id': '630a3d935f6bf41f76dcb2b3', 'ID_Pedido': 31067, 'Importe total': 118.945, 'Fecha de compra': {'$date': '2015-01-18T00:00:00Z'}, 'Número de items': 1, 'Cliente': {'ID_Cliente': 41, 'Nombre': 'Jesús', 'Apellido1': 'Aspas', 'Apellido2': 'Fernández', 'Dirección': {'Incompleto': 'SI'}}}
# {'_id': '630a3d935f6bf41f76dcb2b4', 'ID_Pedido': 73249, 'Importe total': 77.446, 'Fecha de compra': {'$date': '2021-05-27T00:00:00Z'}, 'Número de items': 1, 'Cliente': {'ID_Cliente': 76, 'Nombre': 'Tomás', 'Apellido1': 'Gándara', 'Apellido2': 'Fernández', 'Dirección': {'Incompleto': 'SI'}}}
# {'_id': '630a3d935f6bf41f76dcb2b5', 'ID_Pedido': 29562, 'Importe total': 66.452, 'Fecha de compra': {'$date': '2022-06-10T00:00:00Z'}, 'Número de items': 1, 'Cliente': {'ID_Cliente': 3, 'Nombre': 'Jesús', 'Apellido1': 'González', 'Apellido2': 'Hernández', 'Dirección': {'Incompleto': 'SI'}}}
# {'_id': '630a3d935f6bf41f76dcb2bc', 'ID_Pedido': 62622, 'Importe total': 147.697, 'Fecha de compra': {'$date': '2019-03-14T00:00:00Z'}, 'Número de items': 1, 'Cliente': {'Dirección': {'Incompleto': 'SI'}}}
# {'_id': '630a3d935f6bf41f76dcb2c2', 'ID_Pedido': 50955, 'Importe total': 122.049, 'Fecha de compra': {'$date': '2018-10-16T00:00:00Z'}, 'Número de items': 3, 'Cliente': {'Dirección': {'Incompleto': 'SI'}}}
# {'_id': '630a3d935f6bf41f76dcb2c1', 'ID_Pedido': 30486, 'Importe total': 62.901, 'Fecha de compra': {'$date': '2020-09-11T00:00:00Z'}, 'Número de items': 3, 'Cliente': {'ID_Cliente': 13, 'Nombre': 'Eduardo', 'Apellido1': 'Ferro', 'Apellido2': 'Míguez', 'Dirección': {'Incompleto': 'SI'}}, 'Items': [{'Nombre': 'Pan', 'Importe unitario': 0.75, 'Cantidad': 12}, {'Nombre': 'Leche', 'Importe unitario': 1.06, 'Cantidad': 1}, {'Nombre': 'Queso', 'Importe unitario': 6.57, 'Cantidad': 1}]}
# {'_id': '630a3d935f6bf41f76dcb2c4', 'ID_Pedido': 53960, 'Importe total': 56.183, 'Fecha de compra': {'$date': '2016-01-26T00:00:00Z'}, 'Número de items': 1, 'Cliente': {'Dirección': {'Incompleto': 'SI'}}}
# {'_id': '630a3d935f6bf41f76dcb2cf', 'ID_Pedido': 40359, 'Importe total': 26.489, 'Fecha de compra': {'$date': '2020-05-08T00:00:00Z'}, 'Número de items': 2, 'Cliente': {'ID_Cliente': 67, 'Nombre': 'José', 'Apellido1': 'Ferro', 'Apellido2': 'Álvarez', 'Dirección': {'Incompleto': 'SI'}}, 'Items': [{'Nombre': 'Leche', 'Importe unitario': 2.23, 'Cantidad': 3}]}
# {'_id': '630a3d935f6bf41f76dcb2d3', 'ID_Pedido': 46312, 'Importe total': 106.305, 'Fecha de compra': {'$date': '2017-09-04T00:00:00Z'}, 'Número de items': 3, 'Cliente': {'ID_Cliente': 27, 'Nombre': 'Eduardo', 'Apellido1': 'Aspas', 'Apellido2': 'Míguez', 'Dirección': {'Incompleto': 'SI'}}, 'Items': [{'Nombre': 'Tomates', 'Importe unitario': 2.12, 'Cantidad': 1}, {'Nombre': 'Leche', 'Importe unitario': 1.12, 'Cantidad': 12}, {'Nombre': 'Mermelada', 'Importe unitario': 2.32, 'Cantidad': 2}]}
# {'_id': '630a3d935f6bf41f76dcb2d4', 'ID_Pedido': 54294, 'Importe total': 102.864, 'Fecha de compra': {'$date': '2021-08-11T00:00:00Z'}, 'Número de items': 3, 'Cliente': {'Dirección': {'Incompleto': 'SI'}}}
# {'_id': '630a3d935f6bf41f76dcb2e5', 'ID_Pedido': 73978, 'Importe total': 126.244, 'Fecha de compra': {'$date': '2019-11-24T00:00:00Z'}, 'Número de items': 3, 'Cliente': {'Dirección': {'Incompleto': 'SI'}}}
# {'_id': '630a3d935f6bf41f76dcb2e8', 'ID_Pedido': 25323, 'Importe total': 23.252, 'Fecha de compra': {'$date': '2016-09-03T00:00:00Z'}, 'Número de items': 1, 'Cliente': {'ID_Cliente': 41, 'Nombre': 'Jesús', 'Apellido1': 'Aspas', 'Apellido2': 'Fernández', 'Dirección': {'Incompleto': 'SI'}}, 'Items': [{'Nombre': 'Leche', 'Importe unitario': 1.07, 'Cantidad': 5}, {'Nombre': 'Zumo naranja', 'Importe unitario': 2.98, 'Cantidad': 2}]}
# {'_id': '630a3d935f6bf41f76dcb2eb', 'ID_Pedido': 51013, 'Importe total': 87.261, 'Fecha de compra': {'$date': '2017-06-30T00:00:00Z'}, 'Número de items': 1, 'Cliente': {'Dirección': {'Incompleto': 'SI'}}}
# {'_id': '630a3d935f6bf41f76dcb2ec', 'ID_Pedido': 77074, 'Importe total': 114.118, 'Fecha de compra': {'$date': '2018-01-25T00:00:00Z'}, 'Número de items': 1, 'Cliente': {'ID_Cliente': 3, 'Nombre': 'Jesús', 'Apellido1': 'González', 'Apellido2': 'Hernández', 'Dirección': {'Incompleto': 'SI'}}, 'Items': [{'Nombre': 'Leche', 'Importe unitario': 1.17, 'Cantidad': 6}]}
# {'_id': '630a3d935f6bf41f76dcb2f0', 'ID_Pedido': 10074, 'Importe total': 76.469, 'Fecha de compra': {'$date': '2018-04-15T00:00:00Z'}, 'Número de items': 2, 'Cliente': {'ID_Cliente': 41, 'Nombre': 'Jesús', 'Apellido1': 'Aspas', 'Apellido2': 'Fernández', 'Dirección': {'Incompleto': 'SI'}}, 'Items': [{'Nombre': 'Pan', 'Importe unitario': 0.8, 'Cantidad': 3}, {'Nombre': 'Leche', 'Importe unitario': 1.05, 'Cantidad': 10}]}
# {'_id': '630a3d935f6bf41f76dcb2fa', 'ID_Pedido': 78671, 'Importe total': 18.106, 'Fecha de compra': {'$date': '2017-08-30T00:00:00Z'}, 'Número de items': 2, 'Cliente': {'ID_Cliente': 59, 'Nombre': 'Teresa', 'Apellido1': 'Álvarez', 'Apellido2': 'Hernández', 'Dirección': {'Incompleto': 'SI'}}}
# {'_id': '630a3d935f6bf41f76dcb2fb', 'ID_Pedido': 73339, 'Importe total': 37.781, 'Fecha de compra': {'$date': '2019-07-22T00:00:00Z'}, 'Número de items': 3, 'Cliente': {'ID_Cliente': 83, 'Nombre': 'Arturo', 'Apellido1': 'Ferro', 'Apellido2': 'Hernández', 'Dirección': {'Incompleto': 'SI'}}}
# {'_id': '630a3d935f6bf41f76dcb2fc', 'ID_Pedido': 68481, 'Importe total': 35.162, 'Fecha de compra': {'$date': '2019-01-03T00:00:00Z'}, 'Número de items': 3, 'Cliente': {'ID_Cliente': 59, 'Nombre': 'Teresa', 'Apellido1': 'Álvarez', 'Apellido2': 'Hernández', 'Dirección': {'Incompleto': 'SI'}}}
# {'_id': '630a3d935f6bf41f76dcb2ff', 'ID_Pedido': 13818, 'Importe total': 52.071, 'Fecha de compra': {'$date': '2015-09-12T00:00:00Z'}, 'Número de items': 2, 'Cliente': {'ID_Cliente': 59, 'Nombre': 'Teresa', 'Apellido1': 'Álvarez', 'Apellido2': 'Hernández', 'Dirección': {'Incompleto': 'SI'}}}
# {'_id': '630a3d935f6bf41f76dcb300', 'ID_Pedido': 61917, 'Importe total': 101.401, 'Fecha de compra': {'$date': '2015-08-02T00:00:00Z'}, 'Número de items': 3, 'Cliente': {'ID_Cliente': 31, 'Nombre': 'Álvaro', 'Apellido1': 'Aspas', 'Apellido2': 'Álvarez', 'Dirección': {'Incompleto': 'SI'}}}
# {'_id': '630a3d935f6bf41f76dcb303', 'ID_Pedido': 14468, 'Importe total': 141.129, 'Fecha de compra': {'$date': '2022-01-02T00:00:00Z'}, 'Número de items': 1, 'Cliente': {'ID_Cliente': 41, 'Nombre': 'Jesús', 'Apellido1': 'Aspas', 'Apellido2': 'Fernández', 'Dirección': {'Incompleto': 'SI'}}}
# {'_id': '630a3d935f6bf41f76dcb307', 'ID_Pedido': 61697, 'Importe total': 2.719, 'Fecha de compra': {'$date': '2022-03-10T00:00:00Z'}, 'Número de items': 3, 'Cliente': {'ID_Cliente': 95, 'Nombre': 'Eduardo', 'Apellido1': 'Pérez', 'Apellido2': 'González', 'Dirección': {'Incompleto': 'SI'}}}
# {'_id': '630a3d935f6bf41f76dcb311', 'ID_Pedido': 42633, 'Importe total': 133.599, 'Fecha de compra': {'$date': '2021-02-05T00:00:00Z'}, 'Número de items': 2, 'Cliente': {'ID_Cliente': 41, 'Nombre': 'Jesús', 'Apellido1': 'Aspas', 'Apellido2': 'Fernández', 'Dirección': {'Incompleto': 'SI'}}}
# {'_id': '630a3d935f6bf41f76dcb314', 'ID_Pedido': 82240, 'Importe total': 127.01, 'Fecha de compra': {'$date': '2017-04-19T00:00:00Z'}, 'Número de items': 2, 'Cliente': {'ID_Cliente': 50, 'Nombre': 'María', 'Apellido1': 'Álvarez', 'Apellido2': 'Hernández', 'Dirección': {'Incompleto': 'SI'}}}
# {'_id': '630a3d935f6bf41f76dcb316', 'ID_Pedido': 81176, 'Importe total': 147.958, 'Fecha de compra': {'$date': '2019-10-16T00:00:00Z'}, 'Número de items': 2, 'Cliente': {'ID_Cliente': 3, 'Nombre': 'Jesús', 'Apellido1': 'González', 'Apellido2': 'Hernández', 'Dirección': {'Incompleto': 'SI'}}}
# {'_id': '630a3d935f6bf41f76dcb317', 'ID_Pedido': 57728, 'Importe total': 55.552, 'Fecha de compra': {'$date': '2018-12-22T00:00:00Z'}, 'Número de items': 3, 'Cliente': {'Dirección': {'Incompleto': 'SI'}}}
# {'_id': '630a3d935f6bf41f76dcb31c', 'ID_Pedido': 49601, 'Importe total': 133.861, 'Fecha de compra': {'$date': '2022-08-15T00:00:00Z'}, 'Número de items': 1, 'Cliente': {'Dirección': {'Incompleto': 'SI'}}}
# {'_id': '630a3d935f6bf41f76dcb321', 'ID_Pedido': 32105, 'Importe total': 104.617, 'Fecha de compra': {'$date': '2018-05-15T00:00:00Z'}, 'Número de items': 1, 'Cliente': {'ID_Cliente': 31, 'Nombre': 'Álvaro', 'Apellido1': 'Aspas', 'Apellido2': 'Álvarez', 'Dirección': {'Incompleto': 'SI'}}}
# {'_id': '630a3d935f6bf41f76dcb324', 'ID_Pedido': 24101, 'Importe total': 75.079, 'Fecha de compra': {'$date': '2015-06-11T00:00:00Z'}, 'Número de items': 2, 'Cliente': {'Dirección': {'Incompleto': 'SI'}}}
# {'_id': '630a3d935f6bf41f76dcb328', 'ID_Pedido': 72388, 'Importe total': 79.22, 'Fecha de compra': {'$date': '2022-04-21T00:00:00Z'}, 'Número de items': 3, 'Cliente': {'ID_Cliente': 77, 'Nombre': 'Tomás', 'Apellido1': 'Mosquera', 'Apellido2': 'Martínez', 'Dirección': {'ID_Dirección': 45, 'Calle': 'c/La nave, Zaragoza', 'Código Postal': 50194, 'Localidad': 'El Cazuelo', 'Provincia': 'Zaragoza', 'Incompleto': 'SI'}}}
# {'_id': '630a3d935f6bf41f76dcb332', 'ID_Pedido': 68281, 'Importe total': 57.537, 'Fecha de compra': {'$date': '2020-12-09T00:00:00Z'}, 'Número de items': 1, 'Cliente': {'ID_Cliente': 8, 'Nombre': 'Juan', 'Apellido1': 'Gándara', 'Apellido2': 'Álvarez', 'Dirección': {'Incompleto': 'SI'}}}
# {'_id': '630a3d935f6bf41f76dcb335', 'ID_Pedido': 38026, 'Importe total': 128.344, 'Fecha de compra': {'$date': '2018-04-23T00:00:00Z'}, 'Número de items': 2, 'Cliente': {'ID_Cliente': 83, 'Nombre': 'Arturo', 'Apellido1': 'Ferro', 'Apellido2': 'Hernández', 'Dirección': {'Incompleto': 'SI'}}}
# {'_id': '630a3d935f6bf41f76dcb336', 'ID_Pedido': 35581, 'Importe total': 107.886, 'Fecha de compra': {'$date': '2021-04-23T00:00:00Z'}, 'Número de items': 3, 'Cliente': {'Dirección': {'Incompleto': 'SI'}}}
# {'_id': '630a3d935f6bf41f76dcb338', 'ID_Pedido': 53704, 'Importe total': 89.658, 'Fecha de compra': {'$date': '2016-01-07T00:00:00Z'}, 'Número de items': 3, 'Cliente': {'ID_Cliente': 13, 'Nombre': 'Eduardo', 'Apellido1': 'Ferro', 'Apellido2': 'Míguez', 'Dirección': {'Incompleto': 'SI'}}}
# {'_id': '630a3d935f6bf41f76dcb339', 'ID_Pedido': 57267, 'Importe total': 75.472, 'Fecha de compra': {'$date': '2016-10-16T00:00:00Z'}, 'Número de items': 3, 'Cliente': {'ID_Cliente': 27, 'Nombre': 'Eduardo', 'Apellido1': 'Aspas', 'Apellido2': 'Míguez', 'Dirección': {'Incompleto': 'SI'}}}
# {'_id': '630a3d935f6bf41f76dcb33a', 'ID_Pedido': 31129, 'Importe total': 82.013, 'Fecha de compra': {'$date': '2016-02-25T00:00:00Z'}, 'Número de items': 1, 'Cliente': {'ID_Cliente': 7, 'Nombre': 'Álvaro', 'Apellido1': 'Álvarez', 'Apellido2': 'Pérez', 'Dirección': {'Incompleto': 'SI'}}}
# {'_id': '630a3d935f6bf41f76dcb33c', 'ID_Pedido': 47570, 'Importe total': 115.755, 'Fecha de compra': {'$date': '2020-01-04T00:00:00Z'}, 'Número de items': 3, 'Cliente': {'ID_Cliente': 7, 'Nombre': 'Álvaro', 'Apellido1': 'Álvarez', 'Apellido2': 'Pérez', 'Dirección': {'Incompleto': 'SI'}}}
# {'_id': '630a3d935f6bf41f76dcb340', 'ID_Pedido': 16835, 'Importe total': 127.884, 'Fecha de compra': {'$date': '2018-08-09T00:00:00Z'}, 'Número de items': 3, 'Cliente': {'Dirección': {'Incompleto': 'SI'}}}
# {'_id': '630a3d935f6bf41f76dcb334', 'ID_Pedido': 65899, 'Importe total': 66.466, 'Fecha de compra': {'$date': '2022-08-28T00:00:00Z'}, 'Número de items': 2, 'Cliente': {'ID_Cliente': 7, 'Nombre': 'Álvaro', 'Apellido1': 'Álvarez', 'Apellido2': 'Pérez', 'Dirección': {'Incompleto': 'SI'}}}
# {'_id': '630a3d935f6bf41f76dcb347', 'ID_Pedido': 75660, 'Importe total': 54.026, 'Fecha de compra': {'$date': '2019-12-01T00:00:00Z'}, 'Número de items': 1, 'Cliente': {'ID_Cliente': 13, 'Nombre': 'Eduardo', 'Apellido1': 'Ferro', 'Apellido2': 'Míguez', 'Dirección': {'Incompleto': 'SI'}}}
# {'_id': '630a3d935f6bf41f76dcb355', 'ID_Pedido': 77864, 'Importe total': 16.813, 'Fecha de compra': {'$date': '2017-10-11T00:00:00Z'}, 'Número de items': 3, 'Cliente': {'ID_Cliente': 62, 'Nombre': 'Tomás', 'Apellido1': 'Pérez', 'Apellido2': 'González', 'Dirección': {'Incompleto': 'SI'}}}
# {'_id': '630a3d935f6bf41f76dcb358', 'ID_Pedido': 86240, 'Importe total': 6.652, 'Fecha de compra': {'$date': '2016-04-25T00:00:00Z'}, 'Número de items': 1, 'Cliente': {'Dirección': {'Incompleto': 'SI'}}}
# {'_id': '630a3d935f6bf41f76dcb367', 'ID_Pedido': 52010, 'Importe total': 135.44, 'Fecha de compra': {'$date': '2018-02-26T00:00:00Z'}, 'Número de items': 3, 'Cliente': {'ID_Cliente': 67, 'Nombre': 'José', 'Apellido1': 'Ferro', 'Apellido2': 'Álvarez', 'Dirección': {'Incompleto': 'SI'}}}
# {'_id': '630a3d935f6bf41f76dcb368', 'ID_Pedido': 34059, 'Importe total': 130.583, 'Fecha de compra': {'$date': '2019-05-09T00:00:00Z'}, 'Número de items': 3, 'Cliente': {'ID_Cliente': 31, 'Nombre': 'Álvaro', 'Apellido1': 'Aspas', 'Apellido2': 'Álvarez', 'Dirección': {'Incompleto': 'SI'}}}
# {'_id': '630a3d935f6bf41f76dcb369', 'ID_Pedido': 87420, 'Importe total': 29.626, 'Fecha de compra': {'$date': '2018-11-26T00:00:00Z'}, 'Número de items': 1, 'Cliente': {'Dirección': {'Incompleto': 'SI'}}}
# {'_id': '630a3d935f6bf41f76dcb36d', 'ID_Pedido': 17293, 'Importe total': 131.349, 'Fecha de compra': {'$date': '2022-01-24T00:00:00Z'}, 'Número de items': 3, 'Items': [{'Nombre': 'Leche', 'Importe unitario': 1.07, 'Cantidad': 4}, {'Nombre': 'Zumo naranja', 'Importe unitario': 2.36, 'Cantidad': 6}], 'Cliente': {'Dirección': {'Incompleto': 'SI'}}}
# {'_id': '630a3d935f6bf41f76dcb370', 'ID_Pedido': 46853, 'Importe total': 122.315, 'Fecha de compra': {'$date': '2020-05-08T00:00:00Z'}, 'Número de items': 1, 'Cliente': {'ID_Cliente': 13, 'Nombre': 'Eduardo', 'Apellido1': 'Ferro', 'Apellido2': 'Míguez', 'Dirección': {'Incompleto': 'SI'}}}
# {'_id': '630a3d935f6bf41f76dcb372', 'ID_Pedido': 34485, 'Importe total': 19.615, 'Fecha de compra': {'$date': '2018-01-24T00:00:00Z'}, 'Número de items': 1, 'Cliente': {'ID_Cliente': 3, 'Nombre': 'Jesús', 'Apellido1': 'González', 'Apellido2': 'Hernández', 'Dirección': {'Incompleto': 'SI'}}}
# {'_id': '630a3d935f6bf41f76dcb365', 'ID_Pedido': 52753, 'Importe total': 46.062, 'Fecha de compra': {'$date': '2015-02-04T00:00:00Z'}, 'Número de items': 1, 'Cliente': {'Dirección': {'Incompleto': 'SI'}}}
# {'_id': '630a3d935f6bf41f76dcb377', 'ID_Pedido': 54118, 'Importe total': 94.096, 'Fecha de compra': {'$date': '2020-07-05T00:00:00Z'}, 'Número de items': 1, 'Cliente': {'ID_Cliente': 76, 'Nombre': 'Tomás', 'Apellido1': 'Gándara', 'Apellido2': 'Fernández', 'Dirección': {'Incompleto': 'SI'}}}
# {'_id': '630a3d935f6bf41f76dcb380', 'ID_Pedido': 15345, 'Importe total': 6.666, 'Fecha de compra': {'$date': '2018-04-13T00:00:00Z'}, 'Número de items': 2, 'Items': [{'Nombre': 'Leche', 'Importe unitario': 0.85, 'Cantidad': 4}, {'Nombre': 'Jamón', 'Importe unitario': 2.78, 'Cantidad': 1}], 'Cliente': {'Dirección': {'Incompleto': 'SI'}}}
# {'_id': '630a3d935f6bf41f76dcb381', 'ID_Pedido': 76199, 'Importe total': 104.728, 'Fecha de compra': {'$date': '2015-09-05T00:00:00Z'}, 'Número de items': 2, 'Cliente': {'ID_Cliente': 95, 'Nombre': 'Eduardo', 'Apellido1': 'Pérez', 'Apellido2': 'González', 'Dirección': {'Incompleto': 'SI'}}}
# {'_id': '630a3d935f6bf41f76dcb376', 'ID_Pedido': 22612, 'Importe total': 104.612, 'Fecha de compra': {'$date': '2019-08-22T00:00:00Z'}, 'Número de items': 1, 'Items': [], 'Cliente': {'Dirección': {'Incompleto': 'SI'}}}
# {'_id': '630a3d935f6bf41f76dcb38a', 'ID_Pedido': 32935, 'Importe total': 66.114, 'Fecha de compra': {'$date': '2018-07-14T00:00:00Z'}, 'Número de items': 2, 'Cliente': {'ID_Cliente': 7, 'Nombre': 'Álvaro', 'Apellido1': 'Álvarez', 'Apellido2': 'Pérez', 'Dirección': {'Incompleto': 'SI'}}}
# {'_id': '630a3d935f6bf41f76dcb391', 'ID_Pedido': 69671, 'Importe total': 125.434, 'Fecha de compra': {'$date': '2015-10-17T00:00:00Z'}, 'Número de items': 2, 'Cliente': {'ID_Cliente': 95, 'Nombre': 'Eduardo', 'Apellido1': 'Pérez', 'Apellido2': 'González', 'Dirección': {'Incompleto': 'SI'}}}
# {'_id': '630a3d935f6bf41f76dcb392', 'ID_Pedido': 67505, 'Importe total': 97.4, 'Fecha de compra': {'$date': '2022-05-16T00:00:00Z'}, 'Número de items': 1, 'Cliente': {'ID_Cliente': 74, 'Nombre': 'Álvaro', 'Apellido1': 'Míguez', 'Apellido2': 'Hernández', 'Dirección': {'Incompleto': 'SI'}}, 'Items': [{'Nombre': 'Leche', 'Importe unitario': 1.35, 'Cantidad': 4}, {'Nombre': 'Pasta', 'Importe unitario': 0.96, 'Cantidad': 2}, {'Nombre': 'Zumo naranja', 'Importe unitario': 2.34, 'Cantidad': 4}]}
# {'_id': '630a3d935f6bf41f76dcb396', 'ID_Pedido': 40686, 'Importe total': 118.285, 'Fecha de compra': {'$date': '2022-02-18T00:00:00Z'}, 'Número de items': 1, 'Cliente': {'ID_Cliente': 74, 'Nombre': 'Álvaro', 'Apellido1': 'Míguez', 'Apellido2': 'Hernández', 'Dirección': {'Incompleto': 'SI'}}}
# {'_id': '630a3d935f6bf41f76dcb399', 'ID_Pedido': 62455, 'Importe total': 104.76, 'Fecha de compra': {'$date': '2020-10-16T00:00:00Z'}, 'Número de items': 3, 'Cliente': {'ID_Cliente': 77, 'Nombre': 'Tomás', 'Apellido1': 'Mosquera', 'Apellido2': 'Martínez', 'Dirección': {'ID_Dirección': 45, 'Calle': 'c/La nave, Zaragoza', 'Código Postal': 50194, 'Localidad': 'El Cazuelo', 'Provincia': 'Zaragoza', 'Incompleto': 'SI'}}}
# {'_id': '630a3d935f6bf41f76dcb39b', 'ID_Pedido': 14292, 'Importe total': 103.769, 'Fecha de compra': {'$date': '2021-08-23T00:00:00Z'}, 'Número de items': 1, 'Items': [{'Nombre': 'Tomates', 'Importe unitario': 4.98, 'Cantidad': 2}], 'Cliente': {'Dirección': {'Incompleto': 'SI'}}}
# {'_id': '630a3d935f6bf41f76dcb39e', 'ID_Pedido': 89782, 'Importe total': 29.688, 'Fecha de compra': {'$date': '2018-11-27T00:00:00Z'}, 'Número de items': 2, 'Items': [{'Nombre': 'Leche', 'Importe unitario': 1.17, 'Cantidad': 2}], 'Cliente': {'Dirección': {'Incompleto': 'SI'}}}
# {'_id': '630a3d935f6bf41f76dcb3a4', 'ID_Pedido': 34910, 'Importe total': 135.591, 'Fecha de compra': {'$date': '2019-05-19T00:00:00Z'}, 'Número de items': 3, 'Cliente': {'ID_Cliente': 8, 'Nombre': 'Juan', 'Apellido1': 'Gándara', 'Apellido2': 'Álvarez', 'Dirección': {'Incompleto': 'SI'}}}
# {'_id': '630a3d935f6bf41f76dcb3b0', 'ID_Pedido': 47450, 'Importe total': 150.395, 'Fecha de compra': {'$date': '2019-10-16T00:00:00Z'}, 'Número de items': 3, 'Cliente': {'ID_Cliente': 62, 'Nombre': 'Tomás', 'Apellido1': 'Pérez', 'Apellido2': 'González', 'Dirección': {'Incompleto': 'SI'}}}
# {'_id': '630a3d935f6bf41f76dcb3b2', 'ID_Pedido': 45017, 'Importe total': 124.356, 'Fecha de compra': {'$date': '2018-12-18T00:00:00Z'}, 'Número de items': 2, 'Cliente': {'Dirección': {'Incompleto': 'SI'}}}
# {'_id': '630a3d935f6bf41f76dcb3b9', 'ID_Pedido': 11067, 'Importe total': 98.922, 'Fecha de compra': {'$date': '2017-10-02T00:00:00Z'}, 'Número de items': 1, 'Cliente': {'Dirección': {'Incompleto': 'SI'}}}
# {'_id': '630a3d935f6bf41f76dcb3bc', 'ID_Pedido': 87223, 'Importe total': 43.316, 'Fecha de compra': {'$date': '2022-07-02T00:00:00Z'}, 'Número de items': 2, 'Cliente': {'ID_Cliente': 95, 'Nombre': 'Eduardo', 'Apellido1': 'Pérez', 'Apellido2': 'González', 'Dirección': {'Incompleto': 'SI'}}}
# {'_id': '630a3d935f6bf41f76dcb3be', 'ID_Pedido': 12905, 'Importe total': 49.468, 'Fecha de compra': {'$date': '2018-06-25T00:00:00Z'}, 'Número de items': 1, 'Cliente': {'ID_Cliente': 27, 'Nombre': 'Eduardo', 'Apellido1': 'Aspas', 'Apellido2': 'Míguez', 'Dirección': {'Incompleto': 'SI'}}}
# {'_id': '630a3d935f6bf41f76dcb3c7', 'ID_Pedido': 31600, 'Importe total': 140.667, 'Fecha de compra': {'$date': '2022-12-08T00:00:00Z'}, 'Número de items': 2, 'Cliente': {'ID_Cliente': 74, 'Nombre': 'Álvaro', 'Apellido1': 'Míguez', 'Apellido2': 'Hernández', 'Dirección': {'Incompleto': 'SI'}}}
# {'_id': '630a3d935f6bf41f76dcb3cb', 'ID_Pedido': 11864, 'Importe total': 90.517, 'Fecha de compra': {'$date': '2015-04-30T00:00:00Z'}, 'Número de items': 2, 'Cliente': {'Dirección': {'Incompleto': 'SI'}}}
# {'_id': '630a3d935f6bf41f76dcb3cf', 'ID_Pedido': 56639, 'Importe total': 65.561, 'Fecha de compra': {'$date': '2017-08-11T00:00:00Z'}, 'Número de items': 1, 'Cliente': {'ID_Cliente': 59, 'Nombre': 'Teresa', 'Apellido1': 'Álvarez', 'Apellido2': 'Hernández', 'Dirección': {'Incompleto': 'SI'}}}
# {'_id': '630a3d935f6bf41f76dcb3ce', 'ID_Pedido': 35125, 'Importe total': 102.195, 'Fecha de compra': {'$date': '2019-07-14T00:00:00Z'}, 'Número de items': 2, 'Cliente': {'Dirección': {'Incompleto': 'SI'}}}
# {'_id': '630a3d935f6bf41f76dcb3cd', 'ID_Pedido': 53102, 'Importe total': 14.343, 'Fecha de compra': {'$date': '2019-11-19T00:00:00Z'}, 'Número de items': 3, 'Cliente': {'ID_Cliente': 27, 'Nombre': 'Eduardo', 'Apellido1': 'Aspas', 'Apellido2': 'Míguez', 'Dirección': {'Incompleto': 'SI'}}}
# {'_id': '630a3d935f6bf41f76dcb3db', 'ID_Pedido': 62222, 'Importe total': 16.528, 'Fecha de compra': {'$date': '2018-05-05T00:00:00Z'}, 'Número de items': 3, 'Cliente': {'ID_Cliente': 77, 'Nombre': 'Tomás', 'Apellido1': 'Mosquera', 'Apellido2': 'Martínez', 'Dirección': {'ID_Dirección': 45, 'Calle': 'c/La nave, Zaragoza', 'Código Postal': 50194, 'Localidad': 'El Cazuelo', 'Provincia': 'Zaragoza', 'Incompleto': 'SI'}}}
# {'_id': '630a3d935f6bf41f76dcb3e0', 'ID_Pedido': 33460, 'Importe total': 149.454, 'Fecha de compra': {'$date': '2021-03-03T00:00:00Z'}, 'Número de items': 1, 'Cliente': {'ID_Cliente': 15, 'Nombre': 'Teresa', 'Apellido1': 'Álvarez', 'Apellido2': 'Míguez', 'Dirección': {'Incompleto': 'SI'}}}
# {'_id': '630a3d935f6bf41f76dcb3e2', 'ID_Pedido': 25081, 'Importe total': 69.756, 'Fecha de compra': {'$date': '2019-12-11T00:00:00Z'}, 'Número de items': 3, 'Cliente': {'Dirección': {'Incompleto': 'SI'}}}
# {'_id': '630a3d935f6bf41f76dcb3e5', 'ID_Pedido': 45984, 'Importe total': 93.62, 'Fecha de compra': {'$date': '2018-07-17T00:00:00Z'}, 'Número de items': 1, 'Cliente': {'ID_Cliente': 62, 'Nombre': 'Tomás', 'Apellido1': 'Pérez', 'Apellido2': 'González', 'Dirección': {'Incompleto': 'SI'}}}
# {'_id': '630a3d935f6bf41f76dcb3e9', 'ID_Pedido': 85902, 'Importe total': 125.323, 'Fecha de compra': {'$date': '2017-12-16T00:00:00Z'}, 'Número de items': 2, 'Cliente': {'ID_Cliente': 50, 'Nombre': 'María', 'Apellido1': 'Álvarez', 'Apellido2': 'Hernández', 'Dirección': {'Incompleto': 'SI'}}}
# {'_id': '630a3d935f6bf41f76dcb3ec', 'ID_Pedido': 77452, 'Importe total': 14, 'Fecha de compra': {'$date': '2021-04-01T00:00:00Z'}, 'Número de items': 1, 'Cliente': {'Dirección': {'Incompleto': 'SI'}}}
# {'_id': '630a3d935f6bf41f76dcb3ee', 'ID_Pedido': 22253, 'Importe total': 134.97, 'Fecha de compra': {'$date': '2019-11-16T00:00:00Z'}, 'Número de items': 2, 'Cliente': {'ID_Cliente': 41, 'Nombre': 'Jesús', 'Apellido1': 'Aspas', 'Apellido2': 'Fernández', 'Dirección': {'Incompleto': 'SI'}}}
# {'_id': '630a3d935f6bf41f76dcb3ef', 'ID_Pedido': 22046, 'Importe total': 131.674, 'Fecha de compra': {'$date': '2022-10-11T00:00:00Z'}, 'Número de items': 2, 'Cliente': {'ID_Cliente': 27, 'Nombre': 'Eduardo', 'Apellido1': 'Aspas', 'Apellido2': 'Míguez', 'Dirección': {'Incompleto': 'SI'}}}
# {'_id': '630a3d935f6bf41f76dcb3f0', 'ID_Pedido': 78673, 'Importe total': 106.255, 'Fecha de compra': {'$date': '2018-08-13T00:00:00Z'}, 'Número de items': 1, 'Cliente': {'Dirección': {'Incompleto': 'SI'}}}
# {'_id': '630a3d935f6bf41f76dcb3f1', 'ID_Pedido': 49286, 'Importe total': 9.316, 'Fecha de compra': {'$date': '2020-07-26T00:00:00Z'}, 'Número de items': 2, 'Cliente': {'ID_Cliente': 31, 'Nombre': 'Álvaro', 'Apellido1': 'Aspas', 'Apellido2': 'Álvarez', 'Dirección': {'Incompleto': 'SI'}}}
# {'_id': '630a3d935f6bf41f76dcb3f5', 'ID_Pedido': 37216, 'Importe total': 23.694, 'Fecha de compra': {'$date': '2018-09-11T00:00:00Z'}, 'Número de items': 3, 'Cliente': {'ID_Cliente': 83, 'Nombre': 'Arturo', 'Apellido1': 'Ferro', 'Apellido2': 'Hernández', 'Dirección': {'Incompleto': 'SI'}}}
# {'_id': '630a3d935f6bf41f76dcb3f6', 'ID_Pedido': 55301, 'Importe total': 144.696, 'Fecha de compra': {'$date': '2021-09-20T00:00:00Z'}, 'Número de items': 2, 'Cliente': {'Dirección': {'Incompleto': 'SI'}}}
# {'_id': '630a3d935f6bf41f76dcb3f8', 'ID_Pedido': 89470, 'Importe total': 13.857, 'Fecha de compra': {'$date': '2021-06-02T00:00:00Z'}, 'Número de items': 1, 'Cliente': {'ID_Cliente': 7, 'Nombre': 'Álvaro', 'Apellido1': 'Álvarez', 'Apellido2': 'Pérez', 'Dirección': {'Incompleto': 'SI'}}}
# {'_id': '630a3d935f6bf41f76dcb3fd', 'ID_Pedido': 48511, 'Importe total': 58.645, 'Fecha de compra': {'$date': '2018-12-23T00:00:00Z'}, 'Número de items': 2, 'Cliente': {'ID_Cliente': 59, 'Nombre': 'Teresa', 'Apellido1': 'Álvarez', 'Apellido2': 'Hernández', 'Dirección': {'Incompleto': 'SI'}}}
# {'_id': '630a3d935f6bf41f76dcb406', 'ID_Pedido': 80362, 'Importe total': 146.18, 'Fecha de compra': {'$date': '2019-12-14T00:00:00Z'}, 'Número de items': 1, 'Cliente': {'ID_Cliente': 62, 'Nombre': 'Tomás', 'Apellido1': 'Pérez', 'Apellido2': 'González', 'Dirección': {'Incompleto': 'SI'}}}
# {'_id': '630a3d935f6bf41f76dcb408', 'ID_Pedido': 36491, 'Importe total': 124.045, 'Fecha de compra': {'$date': '2022-04-18T00:00:00Z'}, 'Número de items': 1, 'Cliente': {'ID_Cliente': 3, 'Nombre': 'Jesús', 'Apellido1': 'González', 'Apellido2': 'Hernández', 'Dirección': {'Incompleto': 'SI'}}}
# {'_id': '630a3d935f6bf41f76dcb40b', 'ID_Pedido': 39441, 'Importe total': 96.389, 'Fecha de compra': {'$date': '2020-02-07T00:00:00Z'}, 'Número de items': 3, 'Cliente': {'ID_Cliente': 67, 'Nombre': 'José', 'Apellido1': 'Ferro', 'Apellido2': 'Álvarez', 'Dirección': {'Incompleto': 'SI'}}}
# {'_id': '630a3d935f6bf41f76dcb40d', 'ID_Pedido': 89333, 'Importe total': 13.894, 'Fecha de compra': {'$date': '2018-11-02T00:00:00Z'}, 'Número de items': 3, 'Cliente': {'ID_Cliente': 27, 'Nombre': 'Eduardo', 'Apellido1': 'Aspas', 'Apellido2': 'Míguez', 'Dirección': {'Incompleto': 'SI'}}}
# {'_id': '630a3d935f6bf41f76dcb410', 'ID_Pedido': 48589, 'Importe total': 138.681, 'Fecha de compra': {'$date': '2022-06-21T00:00:00Z'}, 'Número de items': 1, 'Cliente': {'ID_Cliente': 67, 'Nombre': 'José', 'Apellido1': 'Ferro', 'Apellido2': 'Álvarez', 'Dirección': {'Incompleto': 'SI'}}}
# {'_id': '630a3d935f6bf41f76dcb413', 'ID_Pedido': 15983, 'Importe total': 30.208, 'Fecha de compra': {'$date': '2020-01-05T00:00:00Z'}, 'Número de items': 1, 'Cliente': {'ID_Cliente': 27, 'Nombre': 'Eduardo', 'Apellido1': 'Aspas', 'Apellido2': 'Míguez', 'Dirección': {'Incompleto': 'SI'}}}
# {'_id': '630a3d935f6bf41f76dcb41a', 'ID_Pedido': 38636, 'Importe total': 90.452, 'Fecha de compra': {'$date': '2020-11-01T00:00:00Z'}, 'Número de items': 3, 'Cliente': {'ID_Cliente': 7, 'Nombre': 'Álvaro', 'Apellido1': 'Álvarez', 'Apellido2': 'Pérez', 'Dirección': {'Incompleto': 'SI'}}}
# {'_id': '630a3d935f6bf41f76dcb41c', 'ID_Pedido': 39337, 'Importe total': 136.808, 'Fecha de compra': {'$date': '2016-07-28T00:00:00Z'}, 'Número de items': 3, 'Cliente': {'Dirección': {'Incompleto': 'SI'}}}
# {'_id': '630a3d935f6bf41f76dcb41e', 'ID_Pedido': 77092, 'Importe total': 131.989, 'Fecha de compra': {'$date': '2022-04-08T00:00:00Z'}, 'Número de items': 3, 'Cliente': {'ID_Cliente': 13, 'Nombre': 'Eduardo', 'Apellido1': 'Ferro', 'Apellido2': 'Míguez', 'Dirección': {'Incompleto': 'SI'}}}
# {'_id': '630a3d935f6bf41f76dcb41f', 'ID_Pedido': 66959, 'Importe total': 99.202, 'Fecha de compra': {'$date': '2022-11-26T00:00:00Z'}, 'Número de items': 2, 'Cliente': {'ID_Cliente': 27, 'Nombre': 'Eduardo', 'Apellido1': 'Aspas', 'Apellido2': 'Míguez', 'Dirección': {'Incompleto': 'SI'}}}
# {'_id': '630a3d935f6bf41f76dcb423', 'ID_Pedido': 86913, 'Importe total': 148.299, 'Fecha de compra': {'$date': '2018-02-22T00:00:00Z'}, 'Número de items': 3, 'Cliente': {'ID_Cliente': 3, 'Nombre': 'Jesús', 'Apellido1': 'González', 'Apellido2': 'Hernández', 'Dirección': {'Incompleto': 'SI'}}}
# {'_id': '630a3d935f6bf41f76dcb426', 'ID_Pedido': 14495, 'Importe total': 21.564, 'Fecha de compra': {'$date': '2021-05-28T00:00:00Z'}, 'Número de items': 3, 'Cliente': {'ID_Cliente': 41, 'Nombre': 'Jesús', 'Apellido1': 'Aspas', 'Apellido2': 'Fernández', 'Dirección': {'Incompleto': 'SI'}}}
# {'_id': '630a3d935f6bf41f76dcb427', 'ID_Pedido': 30774, 'Importe total': 148.719, 'Fecha de compra': {'$date': '2018-11-03T00:00:00Z'}, 'Número de items': 1, 'Cliente': {'Dirección': {'Incompleto': 'SI'}}}
# {'_id': '630a3d935f6bf41f76dcb428', 'ID_Pedido': 73781, 'Importe total': 36.206, 'Fecha de compra': {'$date': '2021-08-11T00:00:00Z'}, 'Número de items': 2, 'Cliente': {'ID_Cliente': 41, 'Nombre': 'Jesús', 'Apellido1': 'Aspas', 'Apellido2': 'Fernández', 'Dirección': {'Incompleto': 'SI'}}}
# {'_id': '630a3d935f6bf41f76dcb42c', 'ID_Pedido': 89386, 'Importe total': 136.518, 'Fecha de compra': {'$date': '2015-05-05T00:00:00Z'}, 'Número de items': 1, 'Cliente': {'Dirección': {'Incompleto': 'SI'}}}
# {'_id': '630a3d935f6bf41f76dcb431', 'ID_Pedido': 23127, 'Importe total': 122.325, 'Fecha de compra': {'$date': '2020-10-13T00:00:00Z'}, 'Número de items': 1, 'Cliente': {'ID_Cliente': 67, 'Nombre': 'José', 'Apellido1': 'Ferro', 'Apellido2': 'Álvarez', 'Dirección': {'Incompleto': 'SI'}}}
# {'_id': '630a3d935f6bf41f76dcb439', 'ID_Pedido': 75310, 'Importe total': 77.381, 'Fecha de compra': {'$date': '2020-07-05T00:00:00Z'}, 'Número de items': 2, 'Cliente': {'Dirección': {'Incompleto': 'SI'}}}
# {'_id': '630a3d935f6bf41f76dcb43a', 'ID_Pedido': 13792, 'Importe total': 125.418, 'Fecha de compra': {'$date': '2018-03-03T00:00:00Z'}, 'Número de items': 1, 'Cliente': {'Dirección': {'Incompleto': 'SI'}}}
# {'_id': '630a3d935f6bf41f76dcb43c', 'ID_Pedido': 13820, 'Importe total': 134.204, 'Fecha de compra': {'$date': '2015-12-14T00:00:00Z'}, 'Número de items': 2, 'Cliente': {'ID_Cliente': 77, 'Nombre': 'Tomás', 'Apellido1': 'Mosquera', 'Apellido2': 'Martínez', 'Dirección': {'ID_Dirección': 45, 'Calle': 'c/La nave, Zaragoza', 'Código Postal': 50194, 'Localidad': 'El Cazuelo', 'Provincia': 'Zaragoza', 'Incompleto': 'SI'}}}
# {'_id': '630a3d935f6bf41f76dcb43e', 'ID_Pedido': 32807, 'Importe total': 107.394, 'Fecha de compra': {'$date': '2022-01-29T00:00:00Z'}, 'Número de items': 2, 'Cliente': {'ID_Cliente': 76, 'Nombre': 'Tomás', 'Apellido1': 'Gándara', 'Apellido2': 'Fernández', 'Dirección': {'Incompleto': 'SI'}}}
# {'_id': '630a3d935f6bf41f76dcb440', 'ID_Pedido': 53844, 'Importe total': 83.213, 'Fecha de compra': {'$date': '2015-04-05T00:00:00Z'}, 'Número de items': 1, 'Cliente': {'ID_Cliente': 62, 'Nombre': 'Tomás', 'Apellido1': 'Pérez', 'Apellido2': 'González', 'Dirección': {'Incompleto': 'SI'}}}
# {'_id': '630a3d935f6bf41f76dcb441', 'ID_Pedido': 81148, 'Importe total': 138.522, 'Fecha de compra': {'$date': '2017-12-16T00:00:00Z'}, 'Número de items': 1, 'Cliente': {'ID_Cliente': 31, 'Nombre': 'Álvaro', 'Apellido1': 'Aspas', 'Apellido2': 'Álvarez', 'Dirección': {'Incompleto': 'SI'}}}
# {'_id': '630a3d935f6bf41f76dcb443', 'ID_Pedido': 70274, 'Importe total': 85.889, 'Fecha de compra': {'$date': '2017-11-25T00:00:00Z'}, 'Número de items': 1, 'Cliente': {'ID_Cliente': 15, 'Nombre': 'Teresa', 'Apellido1': 'Álvarez', 'Apellido2': 'Míguez', 'Dirección': {'Incompleto': 'SI'}}}
# {'_id': '630a3d935f6bf41f76dcb444', 'ID_Pedido': 35776, 'Importe total': 144.644, 'Fecha de compra': {'$date': '2015-01-01T00:00:00Z'}, 'Número de items': 2, 'Cliente': {'ID_Cliente': 27, 'Nombre': 'Eduardo', 'Apellido1': 'Aspas', 'Apellido2': 'Míguez', 'Dirección': {'Incompleto': 'SI'}}}
# {'_id': '630a3d935f6bf41f76dcb446', 'ID_Pedido': 43411, 'Importe total': 68.478, 'Fecha de compra': {'$date': '2021-04-06T00:00:00Z'}, 'Número de items': 3, 'Cliente': {'ID_Cliente': 62, 'Nombre': 'Tomás', 'Apellido1': 'Pérez', 'Apellido2': 'González', 'Dirección': {'Incompleto': 'SI'}}}
# {'_id': '630a3d935f6bf41f76dcb44b', 'ID_Pedido': 48434, 'Importe total': 18.564, 'Fecha de compra': {'$date': '2022-10-27T00:00:00Z'}, 'Número de items': 3, 'Cliente': {'Dirección': {'Incompleto': 'SI'}}}
# {'_id': '630a3d935f6bf41f76dcb44f', 'ID_Pedido': 50936, 'Importe total': 4.301, 'Fecha de compra': {'$date': '2017-07-13T00:00:00Z'}, 'Número de items': 2, 'Cliente': {'Dirección': {'Incompleto': 'SI'}}}
# {'_id': '630a3d935f6bf41f76dcb456', 'ID_Pedido': 23540, 'Importe total': 32.65, 'Fecha de compra': {'$date': '2018-08-02T00:00:00Z'}, 'Número de items': 2, 'Cliente': {'Dirección': {'Incompleto': 'SI'}}}
# {'_id': '630a3d935f6bf41f76dcb458', 'ID_Pedido': 21149, 'Importe total': 118.132, 'Fecha de compra': {'$date': '2016-01-19T00:00:00Z'}, 'Número de items': 3, 'Cliente': {'Dirección': {'Incompleto': 'SI'}}}
# {'_id': '630a3d935f6bf41f76dcb45f', 'ID_Pedido': 58110, 'Importe total': 70.642, 'Fecha de compra': {'$date': '2017-08-16T00:00:00Z'}, 'Número de items': 2, 'Cliente': {'ID_Cliente': 7, 'Nombre': 'Álvaro', 'Apellido1': 'Álvarez', 'Apellido2': 'Pérez', 'Dirección': {'Incompleto': 'SI'}}}
# {'_id': '630a3d935f6bf41f76dcb462', 'ID_Pedido': 11237, 'Importe total': 75.68, 'Fecha de compra': {'$date': '2016-10-30T00:00:00Z'}, 'Número de items': 1, 'Cliente': {'Dirección': {'Incompleto': 'SI'}}}
# {'_id': '630a3d935f6bf41f76dcb463', 'ID_Pedido': 57798, 'Importe total': 10.11, 'Fecha de compra': {'$date': '2019-03-16T00:00:00Z'}, 'Número de items': 1, 'Cliente': {'ID_Cliente': 83, 'Nombre': 'Arturo', 'Apellido1': 'Ferro', 'Apellido2': 'Hernández', 'Dirección': {'Incompleto': 'SI'}}}
# {'_id': '630a3d935f6bf41f76dcb465', 'ID_Pedido': 75832, 'Importe total': 65.827, 'Fecha de compra': {'$date': '2021-02-09T00:00:00Z'}, 'Número de items': 3, 'Cliente': {'ID_Cliente': 31, 'Nombre': 'Álvaro', 'Apellido1': 'Aspas', 'Apellido2': 'Álvarez', 'Dirección': {'Incompleto': 'SI'}}}
# {'_id': '630a3d935f6bf41f76dcb470', 'ID_Pedido': 29212, 'Importe total': 15.342, 'Fecha de compra': {'$date': '2015-08-05T00:00:00Z'}, 'Número de items': 1, 'Cliente': {'ID_Cliente': 8, 'Nombre': 'Juan', 'Apellido1': 'Gándara', 'Apellido2': 'Álvarez', 'Dirección': {'Incompleto': 'SI'}}}
# {'_id': '630a3d935f6bf41f76dcb46e', 'ID_Pedido': 13454, 'Importe total': 67.089, 'Fecha de compra': {'$date': '2017-08-23T00:00:00Z'}, 'Número de items': 1, 'Cliente': {'ID_Cliente': 77, 'Nombre': 'Tomás', 'Apellido1': 'Mosquera', 'Apellido2': 'Martínez', 'Dirección': {'ID_Dirección': 45, 'Calle': 'c/La nave, Zaragoza', 'Código Postal': 50194, 'Localidad': 'El Cazuelo', 'Provincia': 'Zaragoza', 'Incompleto': 'SI'}}}
# {'_id': '630a3d935f6bf41f76dcb474', 'ID_Pedido': 39007, 'Importe total': 66.449, 'Fecha de compra': {'$date': '2017-04-17T00:00:00Z'}, 'Número de items': 1, 'Cliente': {'Dirección': {'Incompleto': 'SI'}}}
# {'_id': '630a3d935f6bf41f76dcb476', 'ID_Pedido': 10528, 'Importe total': 6.023, 'Fecha de compra': {'$date': '2018-03-12T00:00:00Z'}, 'Número de items': 1, 'Cliente': {'Dirección': {'Incompleto': 'SI'}}}
# {'_id': '630a3d935f6bf41f76dcb479', 'ID_Pedido': 75152, 'Importe total': 38.94, 'Fecha de compra': {'$date': '2017-01-13T00:00:00Z'}, 'Número de items': 3, 'Cliente': {'ID_Cliente': 3, 'Nombre': 'Jesús', 'Apellido1': 'González', 'Apellido2': 'Hernández', 'Dirección': {'Incompleto': 'SI'}}}
# {'_id': '630a3d935f6bf41f76dcb47d', 'ID_Pedido': 75600, 'Importe total': 34.45, 'Fecha de compra': {'$date': '2022-09-12T00:00:00Z'}, 'Número de items': 2, 'Cliente': {'ID_Cliente': 76, 'Nombre': 'Tomás', 'Apellido1': 'Gándara', 'Apellido2': 'Fernández', 'Dirección': {'Incompleto': 'SI'}}}
# {'_id': '630a3d935f6bf41f76dcb483', 'ID_Pedido': 20251, 'Importe total': 42.09, 'Fecha de compra': {'$date': '2022-07-29T00:00:00Z'}, 'Número de items': 2, 'Cliente': {'ID_Cliente': 50, 'Nombre': 'María', 'Apellido1': 'Álvarez', 'Apellido2': 'Hernández', 'Dirección': {'Incompleto': 'SI'}}}
# {'_id': '630a3d935f6bf41f76dcb484', 'ID_Pedido': 14005, 'Importe total': 86.75, 'Fecha de compra': {'$date': '2022-02-28T00:00:00Z'}, 'Número de items': 1, 'Cliente': {'ID_Cliente': 67, 'Nombre': 'José', 'Apellido1': 'Ferro', 'Apellido2': 'Álvarez', 'Dirección': {'Incompleto': 'SI'}}}
# {'_id': '630a3d935f6bf41f76dcb48e', 'ID_Pedido': 29588, 'Importe total': 124.064, 'Fecha de compra': {'$date': '2022-10-18T00:00:00Z'}, 'Número de items': 3, 'Cliente': {'Dirección': {'Incompleto': 'SI'}}}
# {'_id': '630a3d935f6bf41f76dcb492', 'ID_Pedido': 55872, 'Importe total': 102.958, 'Fecha de compra': {'$date': '2016-10-29T00:00:00Z'}, 'Número de items': 3, 'Cliente': {'ID_Cliente': 76, 'Nombre': 'Tomás', 'Apellido1': 'Gándara', 'Apellido2': 'Fernández', 'Dirección': {'Incompleto': 'SI'}}}
# {'_id': '630a3d935f6bf41f76dcb496', 'ID_Pedido': 61929, 'Importe total': 118.766, 'Fecha de compra': {'$date': '2016-08-25T00:00:00Z'}, 'Número de items': 1, 'Cliente': {'Dirección': {'Incompleto': 'SI'}}}
# {'_id': '630a3d935f6bf41f76dcb497', 'ID_Pedido': 13473, 'Importe total': 112.919, 'Fecha de compra': {'$date': '2019-12-20T00:00:00Z'}, 'Número de items': 2, 'Cliente': {'Dirección': {'Incompleto': 'SI'}}}
# {'_id': '630a3d935f6bf41f76dcb498', 'ID_Pedido': 79212, 'Importe total': 143.133, 'Fecha de compra': {'$date': '2016-09-25T00:00:00Z'}, 'Número de items': 2, 'Cliente': {'ID_Cliente': 77, 'Nombre': 'Tomás', 'Apellido1': 'Mosquera', 'Apellido2': 'Martínez', 'Dirección': {'ID_Dirección': 45, 'Calle': 'c/La nave, Zaragoza', 'Código Postal': 50194, 'Localidad': 'El Cazuelo', 'Provincia': 'Zaragoza', 'Incompleto': 'SI'}}}
# {'_id': '630a3d935f6bf41f76dcb49b', 'ID_Pedido': 18140, 'Importe total': 93.943, 'Fecha de compra': {'$date': '2015-09-11T00:00:00Z'}, 'Número de items': 3, 'Cliente': {'Dirección': {'Incompleto': 'SI'}}}
# {'_id': '630a3d935f6bf41f76dcb49e', 'ID_Pedido': 29197, 'Importe total': 46.233, 'Fecha de compra': {'$date': '2019-07-16T00:00:00Z'}, 'Número de items': 1, 'Cliente': {'Dirección': {'Incompleto': 'SI'}}}
# {'_id': '630a3d935f6bf41f76dcb49f', 'ID_Pedido': 83716, 'Importe total': 126.541, 'Fecha de compra': {'$date': '2021-01-07T00:00:00Z'}, 'Número de items': 3, 'Cliente': {'ID_Cliente': 95, 'Nombre': 'Eduardo', 'Apellido1': 'Pérez', 'Apellido2': 'González', 'Dirección': {'Incompleto': 'SI'}}}
# {'_id': '630a3d935f6bf41f76dcb4a5', 'ID_Pedido': 11319, 'Importe total': 124.602, 'Fecha de compra': {'$date': '2018-09-16T00:00:00Z'}, 'Número de items': 3, 'Cliente': {'Dirección': {'Incompleto': 'SI'}}}
# {'_id': '630a3d935f6bf41f76dcb4ac', 'ID_Pedido': 38000, 'Importe total': 84.46, 'Fecha de compra': {'$date': '2020-11-06T00:00:00Z'}, 'Número de items': 2, 'Cliente': {'ID_Cliente': 13, 'Nombre': 'Eduardo', 'Apellido1': 'Ferro', 'Apellido2': 'Míguez', 'Dirección': {'Incompleto': 'SI'}}}
# {'_id': '630a3d935f6bf41f76dcb4b4', 'ID_Pedido': 60493, 'Importe total': 5.062, 'Fecha de compra': {'$date': '2018-03-22T00:00:00Z'}, 'Número de items': 2, 'Cliente': {'Dirección': {'Incompleto': 'SI'}}}
# {'_id': '630a3d935f6bf41f76dcb4b6', 'ID_Pedido': 37632, 'Importe total': 50.888, 'Fecha de compra': {'$date': '2020-03-15T00:00:00Z'}, 'Número de items': 1, 'Cliente': {'Dirección': {'Incompleto': 'SI'}}}
# {'_id': '630a3d935f6bf41f76dcb4bb', 'ID_Pedido': 76462, 'Importe total': 72.825, 'Fecha de compra': {'$date': '2017-12-15T00:00:00Z'}, 'Número de items': 3, 'Cliente': {'ID_Cliente': 50, 'Nombre': 'María', 'Apellido1': 'Álvarez', 'Apellido2': 'Hernández', 'Dirección': {'Incompleto': 'SI'}}}
# {'_id': '630a3d935f6bf41f76dcb4be', 'ID_Pedido': 19230, 'Importe total': 3.461, 'Fecha de compra': {'$date': '2017-11-13T00:00:00Z'}, 'Número de items': 3, 'Cliente': {'ID_Cliente': 15, 'Nombre': 'Teresa', 'Apellido1': 'Álvarez', 'Apellido2': 'Míguez', 'Dirección': {'Incompleto': 'SI'}}}
# {'_id': '630a3d935f6bf41f76dcb4c2', 'ID_Pedido': 16237, 'Importe total': 118.492, 'Fecha de compra': {'$date': '2015-08-23T00:00:00Z'}, 'Número de items': 3, 'Cliente': {'Dirección': {'Incompleto': 'SI'}}}
# {'_id': '630a3d935f6bf41f76dcb4c3', 'ID_Pedido': 77203, 'Importe total': 2.499, 'Fecha de compra': {'$date': '2020-02-04T00:00:00Z'}, 'Número de items': 1, 'Cliente': {'ID_Cliente': 62, 'Nombre': 'Tomás', 'Apellido1': 'Pérez', 'Apellido2': 'González', 'Dirección': {'Incompleto': 'SI'}}}
# {'_id': '630a3d935f6bf41f76dcb4cc', 'ID_Pedido': 71354, 'Importe total': 122.034, 'Fecha de compra': {'$date': '2016-03-01T00:00:00Z'}, 'Número de items': 3, 'Cliente': {'Dirección': {'Incompleto': 'SI'}}}
# {'_id': '630a3d935f6bf41f76dcb4d3', 'ID_Pedido': 21289, 'Importe total': 4.008, 'Fecha de compra': {'$date': '2022-04-16T00:00:00Z'}, 'Número de items': 3, 'Cliente': {'Dirección': {'Incompleto': 'SI'}}}
# {'_id': '630a3d935f6bf41f76dcb4d6', 'ID_Pedido': 64599, 'Importe total': 4.78, 'Fecha de compra': {'$date': '2017-01-27T00:00:00Z'}, 'Número de items': 1, 'Cliente': {'ID_Cliente': 50, 'Nombre': 'María', 'Apellido1': 'Álvarez', 'Apellido2': 'Hernández', 'Dirección': {'Incompleto': 'SI'}}}
# {'_id': '630a3d935f6bf41f76dcb4d8', 'ID_Pedido': 76723, 'Importe total': 71.528, 'Fecha de compra': {'$date': '2015-06-21T00:00:00Z'}, 'Número de items': 2, 'Cliente': {'Dirección': {'Incompleto': 'SI'}}}
# {'_id': '630a3d935f6bf41f76dcb4da', 'ID_Pedido': 50246, 'Importe total': 97.107, 'Fecha de compra': {'$date': '2021-02-25T00:00:00Z'}, 'Número de items': 1, 'Cliente': {'ID_Cliente': 3, 'Nombre': 'Jesús', 'Apellido1': 'González', 'Apellido2': 'Hernández', 'Dirección': {'Incompleto': 'SI'}}}
# {'_id': '630a3d935f6bf41f76dcb4e2', 'ID_Pedido': 30393, 'Importe total': 102.623, 'Fecha de compra': {'$date': '2019-06-11T00:00:00Z'}, 'Número de items': 2, 'Cliente': {'ID_Cliente': 62, 'Nombre': 'Tomás', 'Apellido1': 'Pérez', 'Apellido2': 'González', 'Dirección': {'Incompleto': 'SI'}}}
# {'_id': '630a3d935f6bf41f76dcb4e3', 'ID_Pedido': 37325, 'Importe total': 150.301, 'Fecha de compra': {'$date': '2021-01-10T00:00:00Z'}, 'Número de items': 2, 'Cliente': {'Dirección': {'Incompleto': 'SI'}}}
# {'_id': '630a3d935f6bf41f76dcb4ed', 'ID_Pedido': 74558, 'Importe total': 67.223, 'Fecha de compra': {'$date': '2016-01-20T00:00:00Z'}, 'Número de items': 2, 'Cliente': {'Dirección': {'Incompleto': 'SI'}}}
# {'_id': '630a3d935f6bf41f76dcb4ce', 'ID_Pedido': 87419, 'Importe total': 59.19, 'Fecha de compra': {'$date': '2018-06-27T00:00:00Z'}, 'Número de items': 1, 'Cliente': {'ID_Cliente': 76, 'Nombre': 'Tomás', 'Apellido1': 'Gándara', 'Apellido2': 'Fernández', 'Dirección': {'Incompleto': 'SI'}}}
# {'_id': '630a3d935f6bf41f76dcb4f4', 'ID_Pedido': 38424, 'Importe total': 93.249, 'Fecha de compra': {'$date': '2018-01-06T00:00:00Z'}, 'Número de items': 1, 'Cliente': {'ID_Cliente': 41, 'Nombre': 'Jesús', 'Apellido1': 'Aspas', 'Apellido2': 'Fernández', 'Dirección': {'Incompleto': 'SI'}}}
# {'_id': '630a3d935f6bf41f76dcb4fd', 'ID_Pedido': 39296, 'Importe total': 76.241, 'Fecha de compra': {'$date': '2022-01-05T00:00:00Z'}, 'Número de items': 1, 'Cliente': {'Dirección': {'Incompleto': 'SI'}}}
# {'_id': '630a3d935f6bf41f76dcb4ff', 'ID_Pedido': 35574, 'Importe total': 63.852, 'Fecha de compra': {'$date': '2019-01-22T00:00:00Z'}, 'Número de items': 3, 'Cliente': {'Dirección': {'Incompleto': 'SI'}}}
# {'_id': '630a3d935f6bf41f76dcb4e4', 'ID_Pedido': 68466, 'Importe total': 128.239, 'Fecha de compra': {'$date': '2018-08-06T00:00:00Z'}, 'Número de items': 1, 'Cliente': {'ID_Cliente': 15, 'Nombre': 'Teresa', 'Apellido1': 'Álvarez', 'Apellido2': 'Míguez', 'Dirección': {'Incompleto': 'SI'}}}
# {'_id': '630a3d935f6bf41f76dcb500', 'ID_Pedido': 65514, 'Importe total': 78.675, 'Fecha de compra': {'$date': '2021-04-10T00:00:00Z'}, 'Número de items': 1, 'Cliente': {'Dirección': {'Incompleto': 'SI'}}}
# {'_id': '630a3d935f6bf41f76dcb503', 'ID_Pedido': 34725, 'Importe total': 30.212, 'Fecha de compra': {'$date': '2018-07-11T00:00:00Z'}, 'Número de items': 2, 'Cliente': {'ID_Cliente': 41, 'Nombre': 'Jesús', 'Apellido1': 'Aspas', 'Apellido2': 'Fernández', 'Dirección': {'Incompleto': 'SI'}}}
# {'_id': '630a3d935f6bf41f76dcb504', 'ID_Pedido': 20919, 'Importe total': 60.448, 'Fecha de compra': {'$date': '2017-12-03T00:00:00Z'}, 'Número de items': 1, 'Cliente': {'Dirección': {'Incompleto': 'SI'}}}
# {'_id': '630a3d935f6bf41f76dcb507', 'ID_Pedido': 25158, 'Importe total': 13.664, 'Fecha de compra': {'$date': '2020-03-16T00:00:00Z'}, 'Número de items': 1, 'Cliente': {'ID_Cliente': 74, 'Nombre': 'Álvaro', 'Apellido1': 'Míguez', 'Apellido2': 'Hernández', 'Dirección': {'Incompleto': 'SI'}}}
# {'_id': '630a3d935f6bf41f76dcb509', 'ID_Pedido': 87324, 'Importe total': 69.53, 'Fecha de compra': {'$date': '2019-07-22T00:00:00Z'}, 'Número de items': 3, 'Cliente': {'Dirección': {'Incompleto': 'SI'}}}
# {'_id': '630a3d935f6bf41f76dcb50d', 'ID_Pedido': 29484, 'Importe total': 29.036, 'Fecha de compra': {'$date': '2018-11-16T00:00:00Z'}, 'Número de items': 2, 'Items': [{'Nombre': 'Jamón', 'Importe unitario': 3.82, 'Cantidad': 5}, {'Nombre': 'Leche', 'Importe unitario': 1.05, 'Cantidad': 2}], 'Cliente': {'Dirección': {'Incompleto': 'SI'}}}
# {'_id': '630a3d935f6bf41f76dcb50f', 'ID_Pedido': 63221, 'Importe total': 39.497, 'Fecha de compra': {'$date': '2021-05-24T00:00:00Z'}, 'Número de items': 1, 'Cliente': {'ID_Cliente': 67, 'Nombre': 'José', 'Apellido1': 'Ferro', 'Apellido2': 'Álvarez', 'Dirección': {'Incompleto': 'SI'}}}
# {'_id': '630a3d935f6bf41f76dcb511', 'ID_Pedido': 74576, 'Importe total': 128.999, 'Fecha de compra': {'$date': '2016-05-28T00:00:00Z'}, 'Número de items': 2, 'Cliente': {'Dirección': {'Incompleto': 'SI'}}}
# {'_id': '630a3d935f6bf41f76dcb516', 'ID_Pedido': 24859, 'Importe total': 52.816, 'Fecha de compra': {'$date': '2017-01-01T00:00:00Z'}, 'Número de items': 1, 'Cliente': {'Dirección': {'Incompleto': 'SI'}}}
# {'_id': '630a3d935f6bf41f76dcb519', 'ID_Pedido': 73113, 'Importe total': 111.714, 'Fecha de compra': {'$date': '2019-07-26T00:00:00Z'}, 'Número de items': 2, 'Cliente': {'ID_Cliente': 13, 'Nombre': 'Eduardo', 'Apellido1': 'Ferro', 'Apellido2': 'Míguez', 'Dirección': {'Incompleto': 'SI'}}}
# {'_id': '630a3d935f6bf41f76dcb51a', 'ID_Pedido': 27272, 'Importe total': 147.17, 'Fecha de compra': {'$date': '2017-04-27T00:00:00Z'}, 'Número de items': 3, 'Cliente': {'ID_Cliente': 76, 'Nombre': 'Tomás', 'Apellido1': 'Gándara', 'Apellido2': 'Fernández', 'Dirección': {'Incompleto': 'SI'}}}
# {'_id': '630a3d935f6bf41f76dcb522', 'ID_Pedido': 74702, 'Importe total': 45.228, 'Fecha de compra': {'$date': '2021-04-13T00:00:00Z'}, 'Número de items': 3, 'Cliente': {'ID_Cliente': 62, 'Nombre': 'Tomás', 'Apellido1': 'Pérez', 'Apellido2': 'González', 'Dirección': {'Incompleto': 'SI'}}}
# {'_id': '630a3d935f6bf41f76dcb525', 'ID_Pedido': 30010, 'Importe total': 100.065, 'Fecha de compra': {'$date': '2017-05-16T00:00:00Z'}, 'Número de items': 3, 'Cliente': {'ID_Cliente': 67, 'Nombre': 'José', 'Apellido1': 'Ferro', 'Apellido2': 'Álvarez', 'Dirección': {'Incompleto': 'SI'}}}
# {'_id': '630a3d935f6bf41f76dcb52b', 'ID_Pedido': 60499, 'Importe total': 126.424, 'Fecha de compra': {'$date': '2016-12-21T00:00:00Z'}, 'Número de items': 3, 'Cliente': {'ID_Cliente': 13, 'Nombre': 'Eduardo', 'Apellido1': 'Ferro', 'Apellido2': 'Míguez', 'Dirección': {'Incompleto': 'SI'}}}
# {'_id': '630a3d935f6bf41f76dcb52c', 'ID_Pedido': 54365, 'Importe total': 58.005, 'Fecha de compra': {'$date': '2016-01-30T00:00:00Z'}, 'Número de items': 3, 'Cliente': {'ID_Cliente': 74, 'Nombre': 'Álvaro', 'Apellido1': 'Míguez', 'Apellido2': 'Hernández', 'Dirección': {'Incompleto': 'SI'}}}
# ...
# {'_id': '630a3d935f6bf41f76dcbd7d', 'ID_Pedido': 88988, 'Importe total': 123.471, 'Fecha de compra': {'$date': '2018-04-04T00:00:00Z'}, 'Número de items': 3, 'Cliente': {'Dirección': {'Incompleto': 'SI'}}}
# {'_id': '630a3d935f6bf41f76dcbd7e', 'ID_Pedido': 76922, 'Importe total': 54.863, 'Fecha de compra': {'$date': '2022-09-05T00:00:00Z'}, 'Número de items': 3, 'Cliente': {'ID_Cliente': 7, 'Nombre': 'Álvaro', 'Apellido1': 'Álvarez', 'Apellido2': 'Pérez', 'Dirección': {'Incompleto': 'SI'}}}
# {'_id': '630a3d935f6bf41f76dcbd81', 'ID_Pedido': 81087, 'Importe total': 30.24, 'Fecha de compra': {'$date': '2020-11-11T00:00:00Z'}, 'Número de items': 1, 'Cliente': {'ID_Cliente': 59, 'Nombre': 'Teresa', 'Apellido1': 'Álvarez', 'Apellido2': 'Hernández', 'Dirección': {'Incompleto': 'SI'}}}
# {'_id': '630a3d935f6bf41f76dcbd86', 'ID_Pedido': 52241, 'Importe total': 115.167, 'Fecha de compra': {'$date': '2021-07-18T00:00:00Z'}, 'Número de items': 2, 'Cliente': {'ID_Cliente': 7, 'Nombre': 'Álvaro', 'Apellido1': 'Álvarez', 'Apellido2': 'Pérez', 'Dirección': {'Incompleto': 'SI'}}}
# {'_id': '630a3d935f6bf41f76dcbd8a', 'ID_Pedido': 41944, 'Importe total': 119.309, 'Fecha de compra': {'$date': '2020-11-25T00:00:00Z'}, 'Número de items': 2, 'Cliente': {'ID_Cliente': 50, 'Nombre': 'María', 'Apellido1': 'Álvarez', 'Apellido2': 'Hernández', 'Dirección': {'Incompleto': 'SI'}}}
# {'_id': '630a3d935f6bf41f76dcbd8b', 'ID_Pedido': 34534, 'Importe total': 118.798, 'Fecha de compra': {'$date': '2020-10-30T00:00:00Z'}, 'Número de items': 1, 'Cliente': {'Dirección': {'Incompleto': 'SI'}}}
# {'_id': '630a3d935f6bf41f76dcbd91', 'ID_Pedido': 88445, 'Importe total': 72.508, 'Fecha de compra': {'$date': '2020-06-05T00:00:00Z'}, 'Número de items': 1, 'Cliente': {'Dirección': {'Incompleto': 'SI'}}}
# {'_id': '630a3d935f6bf41f76dcbd90', 'ID_Pedido': 55540, 'Importe total': 129.075, 'Fecha de compra': {'$date': '2017-10-23T00:00:00Z'}, 'Número de items': 2, 'Cliente': {'Dirección': {'Incompleto': 'SI'}}}
# {'_id': '630a3d935f6bf41f76dcbd93', 'ID_Pedido': 14930, 'Importe total': 99.331, 'Fecha de compra': {'$date': '2022-08-01T00:00:00Z'}, 'Número de items': 3, 'Cliente': {'ID_Cliente': 50, 'Nombre': 'María', 'Apellido1': 'Álvarez', 'Apellido2': 'Hernández', 'Dirección': {'Incompleto': 'SI'}}}
# {'_id': '630a3d935f6bf41f76dcbd95', 'ID_Pedido': 75602, 'Importe total': 106.008, 'Fecha de compra': {'$date': '2017-07-20T00:00:00Z'}, 'Número de items': 3, 'Cliente': {'Dirección': {'Incompleto': 'SI'}}}
# {'_id': '630a3d935f6bf41f76dcbd97', 'ID_Pedido': 87632, 'Importe total': 73.891, 'Fecha de compra': {'$date': '2021-04-05T00:00:00Z'}, 'Número de items': 3, 'Cliente': {'ID_Cliente': 41, 'Nombre': 'Jesús', 'Apellido1': 'Aspas', 'Apellido2': 'Fernández', 'Dirección': {'Incompleto': 'SI'}}}
# {'_id': '630a3d935f6bf41f76dcbd98', 'ID_Pedido': 11476, 'Importe total': 125.569, 'Fecha de compra': {'$date': '2021-03-27T00:00:00Z'}, 'Número de items': 2, 'Cliente': {'ID_Cliente': 8, 'Nombre': 'Juan', 'Apellido1': 'Gándara', 'Apellido2': 'Álvarez', 'Dirección': {'Incompleto': 'SI'}}}
# {'_id': '630a3d935f6bf41f76dcbd9a', 'ID_Pedido': 56456, 'Importe total': 139.317, 'Fecha de compra': {'$date': '2018-12-13T00:00:00Z'}, 'Número de items': 2, 'Cliente': {'Dirección': {'Incompleto': 'SI'}}}
# {'_id': '630a3d935f6bf41f76dcbd9c', 'ID_Pedido': 53170, 'Importe total': 85.904, 'Fecha de compra': {'$date': '2021-05-19T00:00:00Z'}, 'Número de items': 1, 'Cliente': {'Dirección': {'Incompleto': 'SI'}}}
# {'_id': '630a3d935f6bf41f76dcbd9d', 'ID_Pedido': 11198, 'Importe total': 24.572, 'Fecha de compra': {'$date': '2021-09-07T00:00:00Z'}, 'Número de items': 1, 'Cliente': {'Dirección': {'Incompleto': 'SI'}}}
# {'_id': '630a3d935f6bf41f76dcbda1', 'ID_Pedido': 38205, 'Importe total': 28.004, 'Fecha de compra': {'$date': '2016-05-24T00:00:00Z'}, 'Número de items': 2, 'Cliente': {'Dirección': {'Incompleto': 'SI'}}}
# {'_id': '630a3d935f6bf41f76dcbda3', 'ID_Pedido': 89303, 'Importe total': 41.406, 'Fecha de compra': {'$date': '2022-08-03T00:00:00Z'}, 'Número de items': 3, 'Cliente': {'ID_Cliente': 41, 'Nombre': 'Jesús', 'Apellido1': 'Aspas', 'Apellido2': 'Fernández', 'Dirección': {'Incompleto': 'SI'}}}
# {'_id': '630a3d935f6bf41f76dcbda6', 'ID_Pedido': 35974, 'Importe total': 60.064, 'Fecha de compra': {'$date': '2020-12-11T00:00:00Z'}, 'Número de items': 3, 'Cliente': {'Dirección': {'Incompleto': 'SI'}}}
# {'_id': '630a3d935f6bf41f76dcbda5', 'ID_Pedido': 27761, 'Importe total': 15.013, 'Fecha de compra': {'$date': '2016-09-10T00:00:00Z'}, 'Número de items': 1, 'Cliente': {'ID_Cliente': 31, 'Nombre': 'Álvaro', 'Apellido1': 'Aspas', 'Apellido2': 'Álvarez', 'Dirección': {'Incompleto': 'SI'}}}
# {'_id': '630a3d935f6bf41f76dcbda8', 'ID_Pedido': 24431, 'Importe total': 22.308, 'Fecha de compra': {'$date': '2022-07-08T00:00:00Z'}, 'Número de items': 2, 'Cliente': {'Dirección': {'Incompleto': 'SI'}}}
# {'_id': '630a3d935f6bf41f76dcbdb2', 'ID_Pedido': 26819, 'Importe total': 86.878, 'Fecha de compra': {'$date': '2021-04-13T00:00:00Z'}, 'Número de items': 2, 'Cliente': {'ID_Cliente': 15, 'Nombre': 'Teresa', 'Apellido1': 'Álvarez', 'Apellido2': 'Míguez', 'Dirección': {'Incompleto': 'SI'}}}
# {'_id': '630a3d935f6bf41f76dcbdb1', 'ID_Pedido': 64358, 'Importe total': 104.733, 'Fecha de compra': {'$date': '2019-04-13T00:00:00Z'}, 'Número de items': 1, 'Cliente': {'ID_Cliente': 62, 'Nombre': 'Tomás', 'Apellido1': 'Pérez', 'Apellido2': 'González', 'Dirección': {'Incompleto': 'SI'}}}
# {'_id': '630a3d935f6bf41f76dcbdc2', 'ID_Pedido': 45827, 'Importe total': 142.147, 'Fecha de compra': {'$date': '2022-10-13T00:00:00Z'}, 'Número de items': 1, 'Cliente': {'Dirección': {'Incompleto': 'SI'}}}
# {'_id': '630a3d935f6bf41f76dcbdb8', 'ID_Pedido': 58601, 'Importe total': 143.535, 'Fecha de compra': {'$date': '2019-10-07T00:00:00Z'}, 'Número de items': 1, 'Cliente': {'ID_Cliente': 3, 'Nombre': 'Jesús', 'Apellido1': 'González', 'Apellido2': 'Hernández', 'Dirección': {'Incompleto': 'SI'}}}
# {'_id': '630a3d935f6bf41f76dcbdc5', 'ID_Pedido': 60740, 'Importe total': 94.093, 'Fecha de compra': {'$date': '2019-01-17T00:00:00Z'}, 'Número de items': 3, 'Cliente': {'ID_Cliente': 95, 'Nombre': 'Eduardo', 'Apellido1': 'Pérez', 'Apellido2': 'González', 'Dirección': {'Incompleto': 'SI'}}}
# {'_id': '630a3d935f6bf41f76dcbdc8', 'ID_Pedido': 19991, 'Importe total': 74.403, 'Fecha de compra': {'$date': '2020-08-17T00:00:00Z'}, 'Número de items': 1, 'Cliente': {'ID_Cliente': 74, 'Nombre': 'Álvaro', 'Apellido1': 'Míguez', 'Apellido2': 'Hernández', 'Dirección': {'Incompleto': 'SI'}}}
# {'_id': '630a3d935f6bf41f76dcbdd2', 'ID_Pedido': 29298, 'Importe total': 144.74, 'Fecha de compra': {'$date': '2015-01-12T00:00:00Z'}, 'Número de items': 3, 'Cliente': {'ID_Cliente': 31, 'Nombre': 'Álvaro', 'Apellido1': 'Aspas', 'Apellido2': 'Álvarez', 'Dirección': {'Incompleto': 'SI'}}}
# {'_id': '630a3d935f6bf41f76dcbdd6', 'ID_Pedido': 63983, 'Importe total': 127.751, 'Fecha de compra': {'$date': '2020-04-21T00:00:00Z'}, 'Número de items': 1, 'Cliente': {'ID_Cliente': 3, 'Nombre': 'Jesús', 'Apellido1': 'González', 'Apellido2': 'Hernández', 'Dirección': {'Incompleto': 'SI'}}}
# {'_id': '630a3d935f6bf41f76dcbdd8', 'ID_Pedido': 32720, 'Importe total': 72.212, 'Fecha de compra': {'$date': '2016-02-18T00:00:00Z'}, 'Número de items': 1, 'Cliente': {'Dirección': {'Incompleto': 'SI'}}}
# {'_id': '630a3d935f6bf41f76dcbddb', 'ID_Pedido': 29952, 'Importe total': 18.848, 'Fecha de compra': {'$date': '2018-01-27T00:00:00Z'}, 'Número de items': 1, 'Cliente': {'Dirección': {'Incompleto': 'SI'}}}
# {'_id': '630a3d935f6bf41f76dcbddc', 'ID_Pedido': 39809, 'Importe total': 118.805, 'Fecha de compra': {'$date': '2018-04-29T00:00:00Z'}, 'Número de items': 1, 'Cliente': {'ID_Cliente': 8, 'Nombre': 'Juan', 'Apellido1': 'Gándara', 'Apellido2': 'Álvarez', 'Dirección': {'Incompleto': 'SI'}}}
# {'_id': '630a3d935f6bf41f76dcbdda', 'ID_Pedido': 19993, 'Importe total': 14.667, 'Fecha de compra': {'$date': '2021-12-01T00:00:00Z'}, 'Número de items': 1, 'Cliente': {'ID_Cliente': 77, 'Nombre': 'Tomás', 'Apellido1': 'Mosquera', 'Apellido2': 'Martínez', 'Dirección': {'ID_Dirección': 45, 'Calle': 'c/La nave, Zaragoza', 'Código Postal': 50194, 'Localidad': 'El Cazuelo', 'Provincia': 'Zaragoza', 'Incompleto': 'SI'}}}
# {'_id': '630a3d935f6bf41f76dcbde2', 'ID_Pedido': 63722, 'Importe total': 57.155, 'Fecha de compra': {'$date': '2017-06-22T00:00:00Z'}, 'Número de items': 1, 'Cliente': {'Dirección': {'Incompleto': 'SI'}}}
# {'_id': '630a3d935f6bf41f76dcbdea', 'ID_Pedido': 73418, 'Importe total': 140.753, 'Fecha de compra': {'$date': '2019-11-11T00:00:00Z'}, 'Número de items': 2, 'Cliente': {'ID_Cliente': 8, 'Nombre': 'Juan', 'Apellido1': 'Gándara', 'Apellido2': 'Álvarez', 'Dirección': {'Incompleto': 'SI'}}}
# {'_id': '630a3d935f6bf41f76dcbdf0', 'ID_Pedido': 74590, 'Importe total': 114.179, 'Fecha de compra': {'$date': '2018-06-20T00:00:00Z'}, 'Número de items': 2, 'Cliente': {'Dirección': {'Incompleto': 'SI'}}}
# {'_id': '630a3d935f6bf41f76dcbdf1', 'ID_Pedido': 62207, 'Importe total': 56.008, 'Fecha de compra': {'$date': '2019-08-27T00:00:00Z'}, 'Número de items': 2, 'Cliente': {'Dirección': {'Incompleto': 'SI'}}}
# {'_id': '630a3d935f6bf41f76dcbdf8', 'ID_Pedido': 66034, 'Importe total': 131.421, 'Fecha de compra': {'$date': '2017-08-14T00:00:00Z'}, 'Número de items': 1, 'Cliente': {'ID_Cliente': 76, 'Nombre': 'Tomás', 'Apellido1': 'Gándara', 'Apellido2': 'Fernández', 'Dirección': {'Incompleto': 'SI'}}}
# {'_id': '630a3d935f6bf41f76dcbdfa', 'ID_Pedido': 38599, 'Importe total': 107.69, 'Fecha de compra': {'$date': '2017-12-08T00:00:00Z'}, 'Número de items': 2, 'Cliente': {'ID_Cliente': 3, 'Nombre': 'Jesús', 'Apellido1': 'González', 'Apellido2': 'Hernández', 'Dirección': {'Incompleto': 'SI'}}}
# {'_id': '630a3d935f6bf41f76dcbdfe', 'ID_Pedido': 10277, 'Importe total': 144.279, 'Fecha de compra': {'$date': '2018-04-21T00:00:00Z'}, 'Número de items': 2, 'Cliente': {'ID_Cliente': 67, 'Nombre': 'José', 'Apellido1': 'Ferro', 'Apellido2': 'Álvarez', 'Dirección': {'Incompleto': 'SI'}}}
# {'_id': '630a3d935f6bf41f76dcbe01', 'ID_Pedido': 46815, 'Importe total': 36.521, 'Fecha de compra': {'$date': '2020-04-21T00:00:00Z'}, 'Número de items': 2, 'Cliente': {'ID_Cliente': 83, 'Nombre': 'Arturo', 'Apellido1': 'Ferro', 'Apellido2': 'Hernández', 'Dirección': {'Incompleto': 'SI'}}}
# {'_id': '630a3d935f6bf41f76dcbe07', 'ID_Pedido': 27245, 'Importe total': 81.334, 'Fecha de compra': {'$date': '2015-03-01T00:00:00Z'}, 'Número de items': 2, 'Cliente': {'ID_Cliente': 8, 'Nombre': 'Juan', 'Apellido1': 'Gándara', 'Apellido2': 'Álvarez', 'Dirección': {'Incompleto': 'SI'}}}
# {'_id': '630a3d935f6bf41f76dcbe0a', 'ID_Pedido': 89350, 'Importe total': 107.449, 'Fecha de compra': {'$date': '2022-06-20T00:00:00Z'}, 'Número de items': 1, 'Cliente': {'ID_Cliente': 76, 'Nombre': 'Tomás', 'Apellido1': 'Gándara', 'Apellido2': 'Fernández', 'Dirección': {'Incompleto': 'SI'}}}
# {'_id': '630a3d935f6bf41f76dcbe0b', 'ID_Pedido': 32098, 'Importe total': 82.694, 'Fecha de compra': {'$date': '2020-04-24T00:00:00Z'}, 'Número de items': 1, 'Cliente': {'Dirección': {'Incompleto': 'SI'}}}
# {'_id': '630a3d935f6bf41f76dcbe0f', 'ID_Pedido': 39933, 'Importe total': 126.113, 'Fecha de compra': {'$date': '2022-03-16T00:00:00Z'}, 'Número de items': 3, 'Cliente': {'ID_Cliente': 74, 'Nombre': 'Álvaro', 'Apellido1': 'Míguez', 'Apellido2': 'Hernández', 'Dirección': {'Incompleto': 'SI'}}}
# {'_id': '630a3d935f6bf41f76dcbe11', 'ID_Pedido': 28283, 'Importe total': 8.696, 'Fecha de compra': {'$date': '2018-10-08T00:00:00Z'}, 'Número de items': 1, 'Cliente': {'ID_Cliente': 83, 'Nombre': 'Arturo', 'Apellido1': 'Ferro', 'Apellido2': 'Hernández', 'Dirección': {'Incompleto': 'SI'}}}
# {'_id': '630a3d935f6bf41f76dcbe13', 'ID_Pedido': 41011, 'Importe total': 147.723, 'Fecha de compra': {'$date': '2022-05-24T00:00:00Z'}, 'Número de items': 2, 'Cliente': {'ID_Cliente': 67, 'Nombre': 'José', 'Apellido1': 'Ferro', 'Apellido2': 'Álvarez', 'Dirección': {'Incompleto': 'SI'}}}
# {'_id': '630a3d935f6bf41f76dcbe1b', 'ID_Pedido': 85181, 'Importe total': 97.916, 'Fecha de compra': {'$date': '2017-12-27T00:00:00Z'}, 'Número de items': 1, 'Cliente': {'Dirección': {'Incompleto': 'SI'}}}
# {'_id': '630a3d935f6bf41f76dcbe1d', 'ID_Pedido': 75796, 'Importe total': 62.735, 'Fecha de compra': {'$date': '2018-07-27T00:00:00Z'}, 'Número de items': 1, 'Cliente': {'ID_Cliente': 8, 'Nombre': 'Juan', 'Apellido1': 'Gándara', 'Apellido2': 'Álvarez', 'Dirección': {'Incompleto': 'SI'}}}
# {'_id': '630a3d935f6bf41f76dcbe1e', 'ID_Pedido': 30122, 'Importe total': 150.247, 'Fecha de compra': {'$date': '2019-01-18T00:00:00Z'}, 'Número de items': 2, 'Cliente': {'Dirección': {'Incompleto': 'SI'}}}
# {'_id': '630a3d935f6bf41f76dcbe28', 'ID_Pedido': 55626, 'Importe total': 127.477, 'Fecha de compra': {'$date': '2019-07-28T00:00:00Z'}, 'Número de items': 1, 'Cliente': {'ID_Cliente': 27, 'Nombre': 'Eduardo', 'Apellido1': 'Aspas', 'Apellido2': 'Míguez', 'Dirección': {'Incompleto': 'SI'}}}
# {'_id': '630a3d935f6bf41f76dcbe29', 'ID_Pedido': 77464, 'Importe total': 34.642, 'Fecha de compra': {'$date': '2017-08-28T00:00:00Z'}, 'Número de items': 1, 'Cliente': {'ID_Cliente': 41, 'Nombre': 'Jesús', 'Apellido1': 'Aspas', 'Apellido2': 'Fernández', 'Dirección': {'Incompleto': 'SI'}}}
# {'_id': '630a3d935f6bf41f76dcbe2f', 'ID_Pedido': 53161, 'Importe total': 128.471, 'Fecha de compra': {'$date': '2016-10-29T00:00:00Z'}, 'Número de items': 2, 'Cliente': {'ID_Cliente': 77, 'Nombre': 'Tomás', 'Apellido1': 'Mosquera', 'Apellido2': 'Martínez', 'Dirección': {'ID_Dirección': 45, 'Calle': 'c/La nave, Zaragoza', 'Código Postal': 50194, 'Localidad': 'El Cazuelo', 'Provincia': 'Zaragoza', 'Incompleto': 'SI'}}}
# {'_id': '630a3d935f6bf41f76dcbe30', 'ID_Pedido': 42811, 'Importe total': 38.193, 'Fecha de compra': {'$date': '2021-02-19T00:00:00Z'}, 'Número de items': 2, 'Cliente': {'Dirección': {'Incompleto': 'SI'}}}
# {'_id': '630a3d935f6bf41f76dcbe2e', 'ID_Pedido': 23547, 'Importe total': 118.671, 'Fecha de compra': {'$date': '2021-09-05T00:00:00Z'}, 'Número de items': 1, 'Cliente': {'ID_Cliente': 15, 'Nombre': 'Teresa', 'Apellido1': 'Álvarez', 'Apellido2': 'Míguez', 'Dirección': {'Incompleto': 'SI'}}}
# {'_id': '630a3d935f6bf41f76dcbe35', 'ID_Pedido': 64566, 'Importe total': 43.645, 'Fecha de compra': {'$date': '2016-08-19T00:00:00Z'}, 'Número de items': 3, 'Cliente': {'Dirección': {'Incompleto': 'SI'}}}
# {'_id': '630a3d935f6bf41f76dcbe37', 'ID_Pedido': 82412, 'Importe total': 82.383, 'Fecha de compra': {'$date': '2015-10-05T00:00:00Z'}, 'Número de items': 1, 'Cliente': {'ID_Cliente': 27, 'Nombre': 'Eduardo', 'Apellido1': 'Aspas', 'Apellido2': 'Míguez', 'Dirección': {'Incompleto': 'SI'}}}
# {'_id': '630a3d935f6bf41f76dcbe3a', 'ID_Pedido': 18780, 'Importe total': 137.106, 'Fecha de compra': {'$date': '2022-04-06T00:00:00Z'}, 'Número de items': 3, 'Cliente': {'ID_Cliente': 3, 'Nombre': 'Jesús', 'Apellido1': 'González', 'Apellido2': 'Hernández', 'Dirección': {'Incompleto': 'SI'}}}
# {'_id': '630a3d935f6bf41f76dcbe3d', 'ID_Pedido': 87008, 'Importe total': 24.648, 'Fecha de compra': {'$date': '2021-02-24T00:00:00Z'}, 'Número de items': 1, 'Cliente': {'ID_Cliente': 67, 'Nombre': 'José', 'Apellido1': 'Ferro', 'Apellido2': 'Álvarez', 'Dirección': {'Incompleto': 'SI'}}}
# {'_id': '630a3d935f6bf41f76dcbe3c', 'ID_Pedido': 20154, 'Importe total': 64.638, 'Fecha de compra': {'$date': '2019-10-15T00:00:00Z'}, 'Número de items': 2, 'Cliente': {'Dirección': {'Incompleto': 'SI'}}}
# {'_id': '630a3d935f6bf41f76dcbe40', 'ID_Pedido': 64092, 'Importe total': 95.923, 'Fecha de compra': {'$date': '2016-07-06T00:00:00Z'}, 'Número de items': 2, 'Cliente': {'ID_Cliente': 50, 'Nombre': 'María', 'Apellido1': 'Álvarez', 'Apellido2': 'Hernández', 'Dirección': {'Incompleto': 'SI'}}}
# {'_id': '630a3d935f6bf41f76dcbe41', 'ID_Pedido': 44462, 'Importe total': 47.114, 'Fecha de compra': {'$date': '2021-09-28T00:00:00Z'}, 'Número de items': 1, 'Cliente': {'Dirección': {'Incompleto': 'SI'}}}
#
# Se actualizaron 0 documentos.

# %%
from pymongo import MongoClient


id_direcciones = [3, 6, 7, 8, 10, 11, 13, 16, 17, 19, 21, 25, 29, 31, 33, 35, 37, 45]

result = collection.update_many(
    {
        "Cliente.Dirección.ID_Dirección": {"$in": id_direcciones},
        "$or": [
            {"Cliente.Dirección.Número": {"$exists": False}},
            {"Cliente.Dirección.Piso": {"$exists": False}}
        ]
    },
    {
        "$set": {"Cliente.Dirección.Incompleto": "SI"}
    }
)

# Imprimir el número de documentos actualizados
print("Se actualizaron", result.modified_count, "documentos.")
# Out:
# Se actualizaron 0 documentos.

# %%
from pymongo import MongoClient
from pymongo.errors import ConnectionFailure

try:
    client = MongoClient('172.18.0.1', 27017)
    client.admin.command('ismaster')
    print("Conexión exitosa")

    db = client.supermercado
    # Seleccionar la colección
    collection = db.pedidos

    result = collection.update_many(
        {"Dirección.Calle": "Avenida de Casablanca 45"},
        {"$set": {"Dirección.Calle": "Avenida de Casablanca"}}
    )

    print(f"Se han actualizado {result.modified_count} documentos.")

except ConnectionFailure:
    print("Error al conectar con el servidor de MongoDB")
# Out:
# Conexión exitosa
# Se han actualizado 0 documentos.

# %%
from pymongo import MongoClient
from pymongo.errors import ConnectionFailure

try:
    client = MongoClient('172.18.0.1', 27017)
    client.admin.command('ismaster')
    print("Conexión exitosa")

    db = client.supermercado
    collection = db.pedidos

    mismatched_addresses = collection.find({
        "Cliente.Dirección": {"$exists": True},
        "$expr": {"$ne": ["$Cliente.Dirección.Localidad", "$Cliente.Dirección.Provincia"]}
    }, {"Cliente.Dirección.ID_Dirección": 1})

    mismatched_address_ids = [doc["Cliente"]["Dirección"]["ID_Dirección"] for doc in mismatched_addresses]

    print("ID de dirección donde la localidad y la provincia no coinciden:")
    for address_id in mismatched_address_ids:
        print(address_id)

except ConnectionFailure:
    print("Error al conectar con el servidor de MongoDB")
# Out:
# Conexión exitosa
# ID de dirección donde la localidad y la provincia no coinciden:
# 10
# 10
# 29
# 8
# 10
# 14
# 42
# 42
# 11
# 29
# 2
# 42
# 21
# 14
# 42
# 35
# 2
# 29
# 14
# 10
# 28
# 10
# 40
# 8
# 10
# 39
# 39
# 40
# 35
# 28
# 14
# 34
# 39
# 35
# 40
# 21
# 42
# 8
# 35
# 35
# 39
# 10
# 39
# 35
# 45
# 8
# 21
# 42
# 12
# 8
# 10
# 35
# 24
# 35
# 14
# 2
# 35
# 12
# 28
# 2
# 2
# 42
# 11
# 40
# 28
# 34
# 8
# 8
# 2
# 34
# 14
# 2
# 42
# 29
# 40
# 24
# 29
# 2
# 10
# 45
# 40
# 35
# 42
# 2
# 2
# 10
# 35
# 3
# 40
# 29
# 8
# 34
# 35
# 2
# 8
# 35
# 42
# 35
# 39
# 8
# 35
# 34
# 35
# 8
# 45
# 8
# 8
# 2
# 10
# 35
# 2
# 39
# 12
# 40
# 35
# 28
# 2
# 11
# 2
# 35
# 40
# 8
# 2
# 35
# 34
# 12
# 35
# 45
# 2
# 28
# 39
# 42
# 3
# 2
# 34
# 8
# 10
# 39
# 24
# 39
# 35
# 8
# 40
# 45
# 10
# 21
# 8
# 40
# 8
# 2
# 39
# 10
# 42
# 2
# 34
# 11
# 39
# 39
# 34
# 2
# 45
# 42
# 42
# 39
# 24
# 28
# 10
# 2
# 29
# 34
# 2
# 42
# 2
# 34
# 3
# 39
# 8
# 35
# 10
# 34
# 39
# 11
# 39
# 42
# 12
# 42
# 8
# 2
# 34
# 40
# 12
# 29
# 2
# 2
# 42
# 39
# 2
# 3
# 35
# 2
# 35
# 40
# 10
# 2
# 39
# 35
# 24
# 35
# 8
# 14
# 14
# 39
# 35
# 12
# 14
# 10
# 34
# 8
# 24
# 12
# 42
# 40
# 35
# 12
# 42
# 8
# 21
# 12
# 12
# 34
# 40
# 10
# 40
# 28
# 28
# 28
# 12
# 21
# 10
# 42
# 28
# 10
# 14
# 11
# 2
# 2
# 40
# 39
# 40
# 10
# 14
# 8
# 42
# 8
# 14
# 42
# 10
# 24
# 10
# 35
# 29
# 12
# 2
# 21
# 12
# 10
# 39
# 42
# 12
# 12
# 39
# 2
# 29
# 10
# 10
# 10
# 3
# 21
# 28
# 42
# 28
# 10
# 45
# 12
# 45
# 28
# 3
# 21
# 35
# 12
# 35
# 3
# 39
# 10
# 39
# 10
# 39
# 12
# 29
# 2
# 3
# 29
# 42
# 45
# 29
# 10
# 40
# 39
# 35
# 11
# 40
# 14
# 3
# 2
# 12
# 35
# 11
# 39
# 42
# 24
# 29
# 2
# 12
# 24
# 2
# 42
# 14
# 35
# 40
# 12
# 10
# 12
# 35
# 34
# 34
# 12
# 34
# 8
# 39
# 8
# 8
# 35
# 11
# 39
# 2
# 42
# 42
# 2
# 35
# 2
# 39
# 35
# 29
# 39
# 29
# 3
# 40
# 24
# 24
# 24
# 10
# 35
# 29
# 24
# 2
# 42
# 2
# 2
# 11
# 12
# 42
# 35
# 8
# 39
# 28
# 2
# 14
# 2
# 35
# 10
# 40
# 3
# 10
# 12
# 29
# 10
# 29
# 8
# 34
# 45
# 35
# 21
# 35
# 3
# 10
# 34
# 14
# 39
# 2
# 10
# 40
# 35
# 28
# 12
# 42
# 29
# 34
# 10
# 12
# 42
# 3
# 40
# 8
# 8
# 11
# 10
# 12
# 10
# 10
# 39
# 12
# 35
# 24
# 40
# 2
# 2
# 2
# 40
# 42
# 40
# 2
# 10
# 39
# 2
# 14
# 39
# 2
# 42
# 3
# 8
# 12
# 2
# 34
# 3
# 11
# 12
# 28
# 42
# 3
# 2
# 11
# 39
# 2
# 35
# 10
# 42
# 40
# 24
# 45
# 12
# 45
# 2
# 40
# 21
# 12
# 12
# 29
# 8
# 2
# 10
# 10
# 35
# 10
# 42
# 39
# 34
# 29
# 21
# 45
# 10
# 2
# 14
# 40
# 35
# 8
# 24
# 42
# 2
# 10
# 35
# 8
# 2
# 10
# 8
# 45
# 2
# 39
# 39
# 42
# 40
# 42
# 29
# 12
# 10
# 39
# 24
# 24
# 28
# 39
# 12
# 39
# 39
# 40
# 45
# 29
# 40
# 35
# 42
# 2
# 2
# 29
# 39
# 3
# 2
# 35
# 10
# 34
# 35
# 29
# 35
# 10
# 28
# 40
# 8
# 29
# 8
# 8
# 24
# 40
# 28
# 8
# 10
# 11
# 34
# 2
# 35
# 10
# 14
# 2
# 40
# 29
# 40
# 34
# 8
# 24
# 24
# 28
# 10
# 35
# 10
# 45
# 40
# 2
# 11
# 8
# 3
# 35
# 2
# 12
# 8
# 28
# 2
# 42
# 2
# 35
# 35
# 8
# 40
# 24
# 42
# 42
# 14
# 35
# 29
# 45
# 40
# 29
# 8
# 24
# 8
# 40
# 8
# 3
# 10
# 45
# 10
# 35
# 21
# 29
# 8
# 40
# 11
# 28
# 45
# 34
# 35
# 3
# 21
# 8
# 2
# 42
# 10
# 28
# 2
# 29
# 39
# 40
# 42
# 45
# 8
# 12
# 42
# 39
# 10
# 45
# 10
# 39
# 35
# 24
# 45
# 34
# 35
# 40
# 3
# 11
# 40
# 42
# 14
# 10
# 10
# 34
# 2
# 35
# 2
# 35
# 28
# 39
# 10
# 34
# 21
# 42
# 3
# 2
# 35
# 2
# 11
# 28
# 35
# 8
# 8
# 21
# 42
# 8
# 45
# 11
# 14
# 24
# 11
# 2
# 39
# 12
# 2
# 8
# 2
# 45
# 10
# 35
# 34
# 35
# 10
# 2
# 10
# 11
# 14
# 45
# 42
# 2
# 2
# 35
# 2
# 39
# 2
# 21
# 11
# 2
# 10
# 2
# 11
# 2
# 35
# 10
# 40
# 2
# 35
# 39
# 10
# 10
# 14
# 3
# 10
# 28
# 8
# 8
# 11
# 14
# 35
# 40
# 29
# 21
# 10
# 35
# 29
# 28
# 10
# 29
# 10
# 42
# 2
# 34
# 12
# 39
# 12
# 34
# 39
# 40
# 10
# 2
# 2
# 35
# 45
# 42
# 2
# 40
# 12
# 28
# 21
# 12
# 40
# 10
# 45
# 42
# 2
# 24
# 3
# 8
# 2
# 14
# 40
# 42
# 10
# 28
# 42
# 21
# 10
# 10
# 2
# 14
# 14
# 14
# 3
# 28
# 34
# 12
# 29
# 35
# 40
# 2
# 2
# 34
# 10
# 12
# 45
# 10
# 35
# 2
# 39
# 2
# 39
# 40
# 35
# 10
# 42
# 42
# 39
# 3
# 35
# 21
# 21
# 10
# 2
# 3
# 42
# 35
# 40
# 39
# 10
# 29
# 2
# 14
# 10
# 12
# 2
# 2
# 10
# 8
# 2
# 2
# 45
# 8
# 2
# 42
# 34
# 35
# 10
# 29
# 2
# 14
# 39
# 28
# 34
# 12
# 14
# 45
# 42
# 21
# 39
# 39
# 11
# 39
# 3
# 12
# 40
# 3
# 34
# 10
# 35
# 10
# 35
# 39
# 8
# 28
# 42
# 40
# 40
# 10
# 2
# 10
# 10
# 42
# 34
# 35
# 2
# 39
# 35
# 42
# 8
# 35
# 39
# 35
# 12
# 40
# 12
# 39
# 10
# 34
# 12
# 10
# 2
# 35
# 3
# 12
# 2
# 29
# 12
# 29
# 29
# 35
# 14
# 2
# 42
# 3
# 2
# 42
# 8
# 35
# 10
# 12
# 10
# 21
# 45
# 14
# 8
# 24
# 11
# 35
# 8
# 10
# 34
# 39
# 35
# 2
# 24
# 10
# 35
# 10
# 2
# 40
# 39
# 45
# 28
# 3
# 10
# 40
# 42
# 40
# 35
# 39
# 29
# 8
# 39
# 21
# 42

# %%
from pymongo import MongoClient
from pymongo.errors import ConnectionFailure

try:
    client = MongoClient('172.18.0.1', 27017)
    client.admin.command('ismaster')
    print("Conexión exitosa")

    db = client.supermercado
    collection = db.pedidos

    orders_with_tomatoes = collection.find({"Items.Nombre": "Tomates"})

    print("Pedidos que contienen algún ítem con nombre 'Tomates':")
    for order in orders_with_tomatoes:
        print(order)

except ConnectionFailure:
    print("Error al conectar con el servidor de MongoDB")
# Out:
# Conexión exitosa
# Pedidos que contienen algún ítem con nombre 'Tomates':
# {'_id': '630a3d935f6bf41f76dcb2d3', 'ID_Pedido': 46312, 'Importe total': 106.305, 'Fecha de compra': {'$date': '2017-09-04T00:00:00Z'}, 'Número de items': 3, 'Cliente': {'ID_Cliente': 27, 'Nombre': 'Eduardo', 'Apellido1': 'Aspas', 'Apellido2': 'Míguez', 'Dirección': {'Incompleto': 'SI'}}, 'Items': [{'Nombre': 'Tomates', 'Importe unitario': 2.12, 'Cantidad': 1}, {'Nombre': 'Leche', 'Importe unitario': 1.12, 'Cantidad': 12}, {'Nombre': 'Mermelada', 'Importe unitario': 2.32, 'Cantidad': 2}]}
# {'_id': '630a3d935f6bf41f76dcb39b', 'ID_Pedido': 14292, 'Importe total': 103.769, 'Fecha de compra': {'$date': '2021-08-23T00:00:00Z'}, 'Número de items': 1, 'Items': [{'Nombre': 'Tomates', 'Importe unitario': 4.98, 'Cantidad': 2}], 'Cliente': {'Dirección': {'Incompleto': 'SI'}}}

# %%
from pymongo import MongoClient
from pymongo.errors import ConnectionFailure

try:
    client = MongoClient('172.18.0.1', 27017)
    client.admin.command('ismaster')
    print("Conexión exitosa")

    db = client.supermercado
    collection = db.pedidos

    order_ids = collection.distinct("ID_Pedido", {"Items.Nombre": {"$all": ["Pan", "Leche"]}})

    print("IDs de Pedido que contienen 'Pan' y 'Leche' entre sus ítems:")
    for order_id in order_ids:
        print(order_id)

except ConnectionFailure:
    print("Error al conectar con el servidor de MongoDB")
# Out:
# Conexión exitosa
# IDs de Pedido que contienen 'Pan' y 'Leche' entre sus ítems:
# 10074
# 30486
# 70812
# 79159
# 87049

# %%
from pymongo import MongoClient

# Establecer conexión con la base de datos
client = MongoClient('172.18.0.1', 27017)
database = client['nombre_de_tu_base_de_datos']  # Reemplaza 'nombre_de_tu_base_de_datos' con el nombre real de tu base de datos

# Contar documentos en la colección "pedidos"
coleccion_pedidos = database['pedidos']
numero_de_documentos = coleccion_pedidos.count_documents({})

print("Número de documentos en la colección 'pedidos':", numero_de_documentos)
# Out:
# Número de documentos en la colección 'pedidos': 0
